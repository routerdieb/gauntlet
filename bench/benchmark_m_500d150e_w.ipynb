# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import numpy as np
import tensorflow as tf
path = r'..\\embeddings\\'
id_dict = {}
word_dict = {}

matrix = []
dimensions = 500
with open(path + "m_base2021_500d_150e_w", 'r' , encoding="utf-8")  as f:
    lines = f.readlines()
    vocab_size = len(lines)
    
    matrix = np.zeros((vocab_size,dimensions),dtype=float)
    for line in lines:
        values = line.split()
        word = values[0].strip()
        id = len(id_dict)
        id_dict[word]=id
        word_dict[id] = word
        vector = np.asarray(values[1:], "double")
        matrix[id_dict[word],:] = vector
print(len(id_dict))
# Out:
# 260377

# %%
def find_candidate(sim,id_a,id_a_star,id_b):
    myList = [id_a, id_b, id_a_star];
    myList.sort();
    
    if(myList[0] != 0):
        index1 = np.argmax(sim[:myList[0]])
    else:
        index1 = None
    sim2 = sim[myList[0]+1:myList[1]]
    if len(sim2) > 0:
        index2 = np.argmax(sim2)
        index2 +=  myList[0]+1
    else:
        index2 = None
    sim3 = sim[myList[1]+1:myList[2]]
    if len(sim3) > 0:
        index3 = np.argmax(sim3)
        index3 +=  myList[1]+1
    else:
        index3 = None
    if(myList[2]+1 < len(sim)):
        index4 = np.argmax(sim[myList[2]+1:])
        index4 +=  myList[2]+1
    else:
        index4 = None
    myList = [index1, index2, index3,index4];
    values = []
    myList2 = []
    for index in myList:
        if index != None:
            values.append(sim[index])
            myList2.append(index)
    index = myList2[np.argmax(values)]
    return index

# %%
matrix_normalized = tf.nn.l2_normalize(matrix,axis = 1)

# %%
def find_nearest_k(searched_word,k):
    list = []
    id = id_dict[searched_word]
    searched_vector = matrix_normalized[id,:] 
    
    for word in id_dict:
        word_weights = matrix_normalized[id_dict[word]]
        loss = tf.tensordot(word_weights,searched_vector,axes = 1).numpy()
        list = insert(list,(word,loss))
        if len(list) > k:
            list = list[0:k+1]
    return list[0:k]

# Function to insert element
def insert(list, tuple):
    (word,n) = tuple
    if(len(list) == 0):
        list = [(word,n)]
    # Searching for the position
    for i in range(len(list)):
        (word_i,n_i) = list[i]
        if n_i < n:
            index = i
            break
      
    # Inserting n in the list
    list = list[:i] + [(word,n)] + list[i:]
    return list


print(find_nearest_k('batman',6))#this should produce one, for the same vectors
print(find_nearest_k('hogwarts',6))
print(find_nearest_k('turing',6))
print(find_nearest_k('florida',6))
#print(find_nearest_k('object-oriented',6))
print(find_nearest_k('dancing',6))
# Out:
# [('batman', 0.9999999999999998), ('superman', 0.6273830433443), ('joker', 0.5280659207871355), ('catwoman', 0.5272311039529596), ('superhero', 0.48298571425138853), ('nightwing', 0.4820262185753492)]
# [('hogwarts', 0.9999999999999996), ('dumbledore', 0.43441635133944034), ('rajdhani', 0.38506617599396964), ('humsafar', 0.3845480987641291), ('tsukuba', 0.3831666272952117), ('kanchenjunga', 0.38303093520430687)]
# [('turing', 0.9999999999999999), ('deterministic', 0.39966130556913976), ('alda', 0.38306674441227645), ('machine', 0.3731029957065046), ('vending', 0.369334867167193), ('dershowitz', 0.36125806253429643)]
# [('florida', 1.0000000000000007), ('miami', 0.5591805687086543), ('alabama', 0.5536634197803354), ('carolina', 0.5380821123573977), ('gainesville', 0.5352767614086814), ('jacksonville', 0.5345697933943235)]
# [('dancing', 0.9999999999999988), ('singing', 0.634503461930655), ('dance', 0.6099806234145523), ('dancers', 0.5979258609182083), ('dancer', 0.5379875236804683), ('dances', 0.5184007360837014)]

# %% [markdown]
# ## 3cosAdd

# %%
def three_cos_predict_np(a,a_star,b,b_star):
    if( a in id_dict and b in id_dict and a_star in id_dict and b_star in id_dict):
        pass
    else:
        return None
    id_a = id_dict[a]
    id_b = id_dict[b]
    id_a_star = id_dict[a_star]
    id_b_star = id_dict[b_star]#remove this after testing
    weight_a = matrix[id_a,:]
    weight_b = matrix[id_b,:]
    weight_a_star = matrix[id_a_star,:]
    direction = weight_b + ( weight_a_star - weight_a)
    direction /= np.linalg.norm(direction)
    
    sim = tf.tensordot(tf.convert_to_tensor(matrix_normalized),tf.convert_to_tensor(direction),axes = 1)
    index = find_candidate(sim,id_a,id_a_star,id_b)
    return word_dict[index]

# %% [markdown]
# # 3cosAdd normalised befor arithmetic

# %%
def three_cos_predict_np_norm(a,a_star,b,b_star):
    if( a in id_dict and b in id_dict and a_star in id_dict and b_star in id_dict):
        pass
    else:
        return None
    id_a = id_dict[a]
    id_b = id_dict[b]
    id_a_star = id_dict[a_star]
    id_b_star = id_dict[b_star]#remove this after testing
    weight_a = matrix_normalized[id_a,:]
    weight_b = matrix_normalized[id_b,:]
    weight_a_star = matrix_normalized[id_a_star,:]
    direction = weight_b + ( weight_a_star - weight_a)
    direction /= np.linalg.norm(direction)
    
    sim = tf.tensordot(tf.convert_to_tensor(matrix_normalized),tf.convert_to_tensor(direction),axes = 1)
    index = find_candidate(sim,id_a,id_a_star,id_b)
    return word_dict[index]

# %% [markdown]
# ## 3cos Mult

# %%
def sim_01(matrix,weight):
    tmp = tf.tensordot(matrix,weight,axes=1)
    tmp = (tmp+1.0)/2.0
    return tmp

def predict_three_cos_mult(a,a_star,b,b_star):
    if( a in id_dict and b in id_dict and a_star in id_dict and b_star in id_dict):
        pass
    else:
        print(a in id_dict)
        print(a_star in id_dict)
        print(b in id_dict)
        print(b_star in id_dict)
        return None
    
    id_a = id_dict[a]
    id_b = id_dict[b]
    id_a_star = id_dict[a_star]
    
    weight_a = matrix_normalized[id_a,:]
    weight_b = matrix_normalized[id_b,:]
    weight_a_star = matrix_normalized[id_a_star,:]
    
    nominator = sim_01(matrix_normalized,weight_a_star) * sim_01(matrix_normalized,weight_b) 
    denominator = sim_01(matrix_normalized,weight_a) + 0.0001
    sim = nominator / denominator
    index = find_candidate(sim,id_a,id_a_star,id_b)
    return word_dict[index]

# %% [markdown]
# # Test all

# %%
count_sem_questions =  0
count_syn_questions =  0

count_sem_sucess      = [0,0,0]
count_syn_sucess      = [0,0,0]

errors = []


files = os.listdir('.\\datasets\\question-data')
for idx,file_name in enumerate(files):
    print(file_name)
    with open('.\\datasets\\question-data\\'+file_name,'r') as file:
        lines = file.readlines()
        local_sucesses    = [0,0,0]
        local_tasks_count = 0
        
        for line_id,line in enumerate(lines):
            if (line_id % 100 == 0):
                print(line_id)
            a,a_star,b,b_star = line.split(" ")
            b_star = b_star.strip()
            #predicted_3cos_add      = three_cos_predict_np(a,a_star,b,b_star)
            predicted_3cos_add_norm = three_cos_predict_np_norm(a,a_star,b,b_star)
            predicted_3cos_mult     = predict_three_cos_mult(a,a_star,b,b_star)
            #print(a,a_star,b,b_star)
            #print(predicted_3cos_add,predicted_3cos_add_norm,predicted_3cos_mult)
            if(idx < 5):#first 5 are sem
                count_sem_questions += 1
                local_tasks_count   += 1
                
                #if predicted_3cos_add      == b_star:
                #    count_sem_sucess[0] += 1
                if predicted_3cos_add_norm == b_star:
                    local_sucesses[1] += 1
                    count_sem_sucess[1] += 1
                    
                if  predicted_3cos_mult    == b_star:
                    local_sucesses[2] += 1
                    count_sem_sucess[2] += 1
            else:
                count_syn_questions += 1
                local_tasks_count   += 1
                
                #if predicted_3cos_add      == b_star:
                #    count_syn_sucess[0] += 1
                if predicted_3cos_add_norm == b_star:
                    local_sucesses[1] += 1
                    count_syn_sucess[1] += 1
                    
                if  predicted_3cos_mult    == b_star:
                    local_sucesses[2] += 1
                    count_syn_sucess[2] += 1
        print(local_sucesses[0]/float(local_tasks_count))
        print(local_sucesses[1]/float(local_tasks_count))
        print(local_sucesses[2]/float(local_tasks_count))
        print('-------------------')

print('semantical')

print(count_sem_sucess[0]/float(count_sem_questions))
print(count_sem_sucess[1]/float(count_sem_questions))
print(count_sem_sucess[2]/float(count_sem_questions))
        
print('syntactical')
print(count_syn_sucess[0]/float(count_sem_questions))
print(count_syn_sucess[1]/float(count_sem_questions))
print(count_syn_sucess[2]/float(count_sem_questions))

print('overall')
print((count_syn_sucess[0]+count_sem_sucess[0])/float(count_sem_questions+count_sem_questions))
print((count_syn_sucess[1]+count_sem_sucess[1])/float(count_sem_questions+count_sem_questions))
print((count_syn_sucess[2]+count_sem_sucess[2])/float(count_sem_questions+count_sem_questions))
# Out:
# capital-common-countries.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 0.0
# 0.9782608695652174
# 0.974308300395257
# -------------------
# capital-world.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 0.0
# 0.8890362511052167
# 0.898762157382847
# -------------------
# city-in-state.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 0.0
# 0.6903121199837859
# 0.7044993919740575
# -------------------
# currency.txt
# 0
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 100
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 200
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 300
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 400
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 500
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# True
# True
# False
# 600
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 700
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 800
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 0.0
# 0.06351039260969978
# 0.09122401847575058
# -------------------
# family.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 0.0
# 0.7964426877470355
# 0.8162055335968379
# -------------------
# gram1-adjective-to-adverb.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0.0
# 0.13205645161290322
# 0.16129032258064516
# -------------------
# gram2-opposite.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 0.0
# 0.25738916256157635
# 0.2438423645320197
# -------------------
# gram3-comparative.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 0.0
# 0.7927927927927928
# 0.8198198198198198
# -------------------
# gram4-superlative.txt
# 0
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 100
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 200
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 300
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 400
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 500
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 600
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 700
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 800
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 900
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# True
# True
# False
# 1000
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# False
# 1100
# True
# True
# True
# False
# 0.0
# 0.26827094474153296
# 0.339572192513369
# -------------------
# gram5-present-participle.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 0.0
# 0.45265151515151514
# 0.4753787878787879
# -------------------
# gram6-nationality-adjective.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 0.0
# 0.8974358974358975
# 0.8943089430894309
# -------------------
# gram7-past-tense.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 0.0
# 0.5282051282051282
# 0.5570512820512821
# -------------------
# gram8-plural.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 0.0
# 0.668918918918919
# 0.6816816816816816
# -------------------
# gram9-plural-verbs.txt
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 0.0
# 0.5735632183908046
# 0.6160919540229886
# -------------------
# semantical
# 0.0
# 0.7529597474348856
# 0.7654752508738302
# syntactical
# 0.0
# 0.6566692975532754
# 0.6850828729281768
# overall
# 0.0
# 0.7048145224940805
# 0.7252790619010034

# %%
print('semantical')

print(count_sem_sucess[0]/float(count_sem_questions))
print(count_sem_sucess[1]/float(count_sem_questions))
print(count_sem_sucess[2]/float(count_sem_questions))
        
print('syntactical')
print(count_syn_sucess[0]/float(count_sem_questions))
print(count_syn_sucess[1]/float(count_sem_questions))
print(count_syn_sucess[2]/float(count_sem_questions))

print('overall')
print((count_syn_sucess[0]+count_sem_sucess[0])/float(count_sem_questions+count_sem_questions))
print((count_syn_sucess[1]+count_sem_sucess[1])/float(count_sem_questions+count_sem_questions))
print((count_syn_sucess[2]+count_sem_sucess[2])/float(count_sem_questions+count_sem_questions))
# Out:
# semantical
# 0.0
# 0.7529597474348856
# 0.7654752508738302
# syntactical
# 0.0
# 0.6566692975532754
# 0.6850828729281768
# overall
# 0.0
# 0.7048145224940805
# 0.7252790619010034

# %%
import winsound
winsound.Beep(440, 500)

# %% [markdown]
# Spearman Rank

# %%
with open(r'.\datasets\wordsim353_sim_rel\wordsim_similarity_goldstandard.txt') as file:

    losses = []
    scores = []

    lines = file.readlines()
    sum_diff = 0
    for line in lines:
        if(len(line) <= 1):
            pass

        print("line" + line)
        word1, word2, score10 = line.split()
        score10 = float(score10)
        try:
            print(word1,word2)
            id1 = id_dict[word1]
            id2 = id_dict[word2]
            #print(id1)
            #print(id2)
            vector1 = matrix_normalized[id1,:]
            vector2 = matrix_normalized[id2,:]
            #print(vector1)
            #print(vector2)
            loss = sim_01(vector1,vector2)
        except: 
            loss = 0
        print(str(loss),str(score10/10.0))
        sum_diff += abs((score10/10.0) - loss)
        losses.append(loss)
        scores.append(score10/10.0)
    print('Average Distance between prediction and hand assigned is ' + str(sum_diff / len(lines)))
# Out:
# linetiger	cat	7.35
#
# tiger cat
# tf.Tensor(0.6934915120768786, shape=(), dtype=float64) 0.735
# linetiger	tiger	10.00
#
# tiger tiger
# tf.Tensor(1.0, shape=(), dtype=float64) 1.0
# lineplane	car	5.77
#
# plane car
# tf.Tensor(0.6795920009156688, shape=(), dtype=float64) 0.577
# linetrain	car	6.31
#
# train car
# tf.Tensor(0.7417733554379867, shape=(), dtype=float64) 0.631
# linetelevision	radio	6.77
#
# television radio
# tf.Tensor(0.7969138494723481, shape=(), dtype=float64) 0.6769999999999999
# linemedia	radio	7.42
#
# media radio
# tf.Tensor(0.7113135868329117, shape=(), dtype=float64) 0.742
# linebread	butter	6.19
#
# bread butter
# tf.Tensor(0.7660938041078724, shape=(), dtype=float64) 0.619
# linecucumber	potato	5.92
#
# cucumber potato
# tf.Tensor(0.6866004482867368, shape=(), dtype=float64) 0.592
# linedoctor	nurse	7.00
#
# doctor nurse
# tf.Tensor(0.7046488948180128, shape=(), dtype=float64) 0.7
# lineprofessor	doctor	6.62
#
# professor doctor
# tf.Tensor(0.6983823929583671, shape=(), dtype=float64) 0.662
# linestudent	professor	6.81
#
# student professor
# tf.Tensor(0.6628822590886335, shape=(), dtype=float64) 0.6809999999999999
# linesmart	stupid	5.81
#
# smart stupid
# tf.Tensor(0.6387521185973768, shape=(), dtype=float64) 0.581
# linewood	forest	7.73
#
# wood forest
# tf.Tensor(0.6945376255585058, shape=(), dtype=float64) 0.773
# linemoney	cash	9.15
#
# money cash
# tf.Tensor(0.7724900751521289, shape=(), dtype=float64) 0.915
# lineking	queen	8.58
#
# king queen
# tf.Tensor(0.781801563285641, shape=(), dtype=float64) 0.858
# lineking	rook	5.92
#
# king rook
# tf.Tensor(0.5958873845814359, shape=(), dtype=float64) 0.592
# linebishop	rabbi	6.69
#
# bishop rabbi
# tf.Tensor(0.6602484021922583, shape=(), dtype=float64) 0.669
# linefuck	sex	9.44
#
# fuck sex
# tf.Tensor(0.5778357192654151, shape=(), dtype=float64) 0.944
# linefootball	soccer	9.03
#
# football soccer
# tf.Tensor(0.7953612187115168, shape=(), dtype=float64) 0.9029999999999999
# linefootball	basketball	6.81
#
# football basketball
# tf.Tensor(0.8335896084518295, shape=(), dtype=float64) 0.6809999999999999
# linefootball	tennis	6.63
#
# football tennis
# tf.Tensor(0.698418354133127, shape=(), dtype=float64) 0.663
# lineArafat	Jackson	2.50
#
# Arafat Jackson
# 0 0.25
# linephysics	chemistry	7.35
#
# physics chemistry
# tf.Tensor(0.85558815954616, shape=(), dtype=float64) 0.735
# linevodka	gin	8.46
#
# vodka gin
# tf.Tensor(0.6998862508510932, shape=(), dtype=float64) 0.8460000000000001
# linevodka	brandy	8.13
#
# vodka brandy
# tf.Tensor(0.7015176143073221, shape=(), dtype=float64) 0.8130000000000001
# linedrink	eat	6.87
#
# drink eat
# tf.Tensor(0.7512528693689896, shape=(), dtype=float64) 0.687
# linecar	automobile	8.94
#
# car automobile
# tf.Tensor(0.7916177903352841, shape=(), dtype=float64) 0.8939999999999999
# linegem	jewel	8.96
#
# gem jewel
# tf.Tensor(0.659352995341431, shape=(), dtype=float64) 0.8960000000000001
# linejourney	voyage	9.29
#
# journey voyage
# tf.Tensor(0.7876939197016606, shape=(), dtype=float64) 0.9289999999999999
# lineboy	lad	8.83
#
# boy lad
# tf.Tensor(0.621966421031406, shape=(), dtype=float64) 0.883
# linecoast	shore	9.10
#
# coast shore
# tf.Tensor(0.7461712939991858, shape=(), dtype=float64) 0.9099999999999999
# lineasylum	madhouse	8.87
#
# asylum madhouse
# tf.Tensor(0.5476763371768041, shape=(), dtype=float64) 0.8869999999999999
# linemagician	wizard	9.02
#
# magician wizard
# tf.Tensor(0.673992669313963, shape=(), dtype=float64) 0.9019999999999999
# linemidday	noon	9.29
#
# midday noon
# tf.Tensor(0.8114485523652738, shape=(), dtype=float64) 0.9289999999999999
# linefurnace	stove	8.79
#
# furnace stove
# tf.Tensor(0.7339621098029998, shape=(), dtype=float64) 0.8789999999999999
# linefood	fruit	7.52
#
# food fruit
# tf.Tensor(0.6735594047778751, shape=(), dtype=float64) 0.752
# linebird	cock	7.10
#
# bird cock
# tf.Tensor(0.6115352054642071, shape=(), dtype=float64) 0.71
# linebird	crane	7.38
#
# bird crane
# tf.Tensor(0.6575994530840075, shape=(), dtype=float64) 0.738
# linefood	rooster	4.42
#
# food rooster
# tf.Tensor(0.5739618611231083, shape=(), dtype=float64) 0.442
# linemoney	dollar	8.42
#
# money dollar
# tf.Tensor(0.6538708893455345, shape=(), dtype=float64) 0.842
# linemoney	currency	9.04
#
# money currency
# tf.Tensor(0.6778331151943556, shape=(), dtype=float64) 0.9039999999999999
# linetiger	jaguar	8.00
#
# tiger jaguar
# tf.Tensor(0.6259391966830775, shape=(), dtype=float64) 0.8
# linetiger	feline	8.00
#
# tiger feline
# tf.Tensor(0.6113519376288568, shape=(), dtype=float64) 0.8
# linetiger	carnivore	7.08
#
# tiger carnivore
# tf.Tensor(0.5587094177500348, shape=(), dtype=float64) 0.708
# linetiger	mammal	6.85
#
# tiger mammal
# tf.Tensor(0.5768202494574088, shape=(), dtype=float64) 0.6849999999999999
# linetiger	animal	7.00
#
# tiger animal
# tf.Tensor(0.5916072484028916, shape=(), dtype=float64) 0.7
# linetiger	organism	4.77
#
# tiger organism
# tf.Tensor(0.5642807604027439, shape=(), dtype=float64) 0.477
# linetiger	fauna	5.62
#
# tiger fauna
# tf.Tensor(0.6119933011242693, shape=(), dtype=float64) 0.562
# linepsychology	psychiatry	8.08
#
# psychology psychiatry
# tf.Tensor(0.7960007814971821, shape=(), dtype=float64) 0.808
# linepsychology	science	6.71
#
# psychology science
# tf.Tensor(0.7451451489123861, shape=(), dtype=float64) 0.671
# linepsychology	discipline	5.58
#
# psychology discipline
# tf.Tensor(0.6763818851572703, shape=(), dtype=float64) 0.558
# lineplanet	star	8.45
#
# planet star
# tf.Tensor(0.704063004104639, shape=(), dtype=float64) 0.845
# lineplanet	moon	8.08
#
# planet moon
# tf.Tensor(0.6869560413072137, shape=(), dtype=float64) 0.808
# lineplanet	sun	8.02
#
# planet sun
# tf.Tensor(0.6708902728436984, shape=(), dtype=float64) 0.8019999999999999
# lineprecedent	example	5.85
#
# precedent example
# tf.Tensor(0.6489733410397449, shape=(), dtype=float64) 0.585
# lineprecedent	antecedent	6.04
#
# precedent antecedent
# tf.Tensor(0.6484903214974373, shape=(), dtype=float64) 0.604
# linecup	tableware	6.85
#
# cup tableware
# tf.Tensor(0.5742425878334514, shape=(), dtype=float64) 0.6849999999999999
# linecup	artifact	2.92
#
# cup artifact
# tf.Tensor(0.5699939084680485, shape=(), dtype=float64) 0.292
# linecup	object	3.69
#
# cup object
# tf.Tensor(0.541023689036272, shape=(), dtype=float64) 0.369
# linecup	entity	2.15
#
# cup entity
# tf.Tensor(0.5457825946056016, shape=(), dtype=float64) 0.215
# linejaguar	cat	7.42
#
# jaguar cat
# tf.Tensor(0.5998839656380367, shape=(), dtype=float64) 0.742
# linejaguar	car	7.27
#
# jaguar car
# tf.Tensor(0.6475800688113299, shape=(), dtype=float64) 0.727
# linemile	kilometer	8.66
#
# mile kilometer
# tf.Tensor(0.7903283378626111, shape=(), dtype=float64) 0.866
# lineskin	eye	6.22
#
# skin eye
# tf.Tensor(0.7242880478441225, shape=(), dtype=float64) 0.622
# lineJapanese	American	6.50
#
# Japanese American
# 0 0.65
# linecentury	year	7.59
#
# century year
# tf.Tensor(0.672674080833232, shape=(), dtype=float64) 0.759
# lineannouncement	news	7.56
#
# announcement news
# tf.Tensor(0.657259871116803, shape=(), dtype=float64) 0.756
# linedoctor	personnel	5.00
#
# doctor personnel
# tf.Tensor(0.6161331244346703, shape=(), dtype=float64) 0.5
# lineHarvard	Yale	8.13
#
# Harvard Yale
# 0 0.8130000000000001
# linehospital	infrastructure	4.63
#
# hospital infrastructure
# tf.Tensor(0.5999433469114437, shape=(), dtype=float64) 0.46299999999999997
# linelife	death	7.88
#
# life death
# tf.Tensor(0.7485539038422208, shape=(), dtype=float64) 0.788
# linetravel	activity	5.00
#
# travel activity
# tf.Tensor(0.6389073745492281, shape=(), dtype=float64) 0.5
# linetype	kind	8.97
#
# type kind
# tf.Tensor(0.724880469129757, shape=(), dtype=float64) 0.897
# linestreet	place	6.44
#
# street place
# tf.Tensor(0.6925659367339809, shape=(), dtype=float64) 0.644
# linestreet	avenue	8.88
#
# street avenue
# tf.Tensor(0.8092986911749036, shape=(), dtype=float64) 0.8880000000000001
# linestreet	block	6.88
#
# street block
# tf.Tensor(0.6426617010361501, shape=(), dtype=float64) 0.688
# linecell	phone	7.81
#
# cell phone
# tf.Tensor(0.6953417693945727, shape=(), dtype=float64) 0.7809999999999999
# linedividend	payment	7.63
#
# dividend payment
# tf.Tensor(0.6776981370819397, shape=(), dtype=float64) 0.763
# linecalculation	computation	8.44
#
# calculation computation
# tf.Tensor(0.7591717757872327, shape=(), dtype=float64) 0.844
# lineprofit	loss	7.63
#
# profit loss
# tf.Tensor(0.6322845259790293, shape=(), dtype=float64) 0.763
# linedollar	yen	7.78
#
# dollar yen
# tf.Tensor(0.7311738527126919, shape=(), dtype=float64) 0.778
# linedollar	buck	9.22
#
# dollar buck
# tf.Tensor(0.5636484586350222, shape=(), dtype=float64) 0.922
# linephone	equipment	7.13
#
# phone equipment
# tf.Tensor(0.634527365500243, shape=(), dtype=float64) 0.713
# lineliquid	water	7.89
#
# liquid water
# tf.Tensor(0.6961442023694439, shape=(), dtype=float64) 0.7889999999999999
# linemarathon	sprint	7.47
#
# marathon sprint
# tf.Tensor(0.6967664099955589, shape=(), dtype=float64) 0.747
# lineseafood	food	8.34
#
# seafood food
# tf.Tensor(0.6862371697659514, shape=(), dtype=float64) 0.834
# lineseafood	lobster	8.70
#
# seafood lobster
# tf.Tensor(0.7144950975773185, shape=(), dtype=float64) 0.8699999999999999
# linelobster	food	7.81
#
# lobster food
# tf.Tensor(0.5903675081489664, shape=(), dtype=float64) 0.7809999999999999
# linelobster	wine	5.70
#
# lobster wine
# tf.Tensor(0.6049969039048207, shape=(), dtype=float64) 0.5700000000000001
# linechampionship	tournament	8.36
#
# championship tournament
# tf.Tensor(0.8117395841700767, shape=(), dtype=float64) 0.836
# lineman	woman	8.30
#
# man woman
# tf.Tensor(0.8440065328964899, shape=(), dtype=float64) 0.8300000000000001
# lineman	governor	5.25
#
# man governor
# tf.Tensor(0.6083951996834984, shape=(), dtype=float64) 0.525
# linemurder	manslaughter	8.53
#
# murder manslaughter
# tf.Tensor(0.7352059014608574, shape=(), dtype=float64) 0.853
# lineopera	performance	6.88
#
# opera performance
# tf.Tensor(0.6785132588867958, shape=(), dtype=float64) 0.688
# lineMexico	Brazil	7.44
#
# Mexico Brazil
# 0 0.744
# lineglass	metal	5.56
#
# glass metal
# tf.Tensor(0.6969118430850989, shape=(), dtype=float64) 0.5559999999999999
# linealuminum	metal	7.83
#
# aluminum metal
# tf.Tensor(0.7181209074599914, shape=(), dtype=float64) 0.783
# linerock	jazz	7.59
#
# rock jazz
# tf.Tensor(0.7370732974934063, shape=(), dtype=float64) 0.759
# linemuseum	theater	7.19
#
# museum theater
# tf.Tensor(0.6707890228261358, shape=(), dtype=float64) 0.7190000000000001
# lineshower	thunderstorm	6.31
#
# shower thunderstorm
# tf.Tensor(0.6909035315370754, shape=(), dtype=float64) 0.631
# linemonk	oracle	5.00
#
# monk oracle
# tf.Tensor(0.5971457000436882, shape=(), dtype=float64) 0.5
# linecup	food	5.00
#
# cup food
# tf.Tensor(0.582377750213686, shape=(), dtype=float64) 0.5
# linejournal	association	4.97
#
# journal association
# tf.Tensor(0.6841030452832403, shape=(), dtype=float64) 0.497
# linestreet	children	4.94
#
# street children
# tf.Tensor(0.6280503230898551, shape=(), dtype=float64) 0.49400000000000005
# linecar	flight	4.94
#
# car flight
# tf.Tensor(0.6397731757887278, shape=(), dtype=float64) 0.49400000000000005
# linespace	chemistry	4.88
#
# space chemistry
# tf.Tensor(0.5949660674219502, shape=(), dtype=float64) 0.488
# linesituation	conclusion	4.81
#
# situation conclusion
# tf.Tensor(0.6655153580012335, shape=(), dtype=float64) 0.481
# lineword	similarity	4.75
#
# word similarity
# tf.Tensor(0.6173414295573663, shape=(), dtype=float64) 0.475
# linepeace	plan	4.75
#
# peace plan
# tf.Tensor(0.6195855787644009, shape=(), dtype=float64) 0.475
# lineconsumer	energy	4.75
#
# consumer energy
# tf.Tensor(0.6430172461346806, shape=(), dtype=float64) 0.475
# lineministry	culture	4.69
#
# ministry culture
# tf.Tensor(0.6880021199605177, shape=(), dtype=float64) 0.46900000000000003
# linesmart	student	4.62
#
# smart student
# tf.Tensor(0.6236386580452966, shape=(), dtype=float64) 0.462
# lineinvestigation	effort	4.59
#
# investigation effort
# tf.Tensor(0.6628234843775563, shape=(), dtype=float64) 0.45899999999999996
# lineimage	surface	4.56
#
# image surface
# tf.Tensor(0.6483437273914168, shape=(), dtype=float64) 0.45599999999999996
# linelife	term	4.50
#
# life term
# tf.Tensor(0.6824276353400162, shape=(), dtype=float64) 0.45
# linestart	match	4.47
#
# start match
# tf.Tensor(0.6719094189663326, shape=(), dtype=float64) 0.44699999999999995
# linecomputer	news	4.47
#
# computer news
# tf.Tensor(0.6096913040815404, shape=(), dtype=float64) 0.44699999999999995
# lineboard	recommendation	4.47
#
# board recommendation
# tf.Tensor(0.6375364989277942, shape=(), dtype=float64) 0.44699999999999995
# linelad	brother	4.46
#
# lad brother
# tf.Tensor(0.58349071688971, shape=(), dtype=float64) 0.446
# lineobservation	architecture	4.38
#
# observation architecture
# tf.Tensor(0.5777688605335766, shape=(), dtype=float64) 0.438
# linecoast	hill	4.38
#
# coast hill
# tf.Tensor(0.6420176080986204, shape=(), dtype=float64) 0.438
# linedeployment	departure	4.25
#
# deployment departure
# tf.Tensor(0.6733436117431415, shape=(), dtype=float64) 0.425
# linebenchmark	index	4.25
#
# benchmark index
# tf.Tensor(0.650932335718427, shape=(), dtype=float64) 0.425
# lineattempt	peace	4.25
#
# attempt peace
# tf.Tensor(0.644181452096129, shape=(), dtype=float64) 0.425
# lineconsumer	confidence	4.13
#
# consumer confidence
# tf.Tensor(0.6153250819582082, shape=(), dtype=float64) 0.413
# linestart	year	4.06
#
# start year
# tf.Tensor(0.7035457101523086, shape=(), dtype=float64) 0.40599999999999997
# linefocus	life	4.06
#
# focus life
# tf.Tensor(0.6787041860872223, shape=(), dtype=float64) 0.40599999999999997
# linedevelopment	issue	3.97
#
# development issue
# tf.Tensor(0.6230836823041638, shape=(), dtype=float64) 0.397
# linetheater	history	3.91
#
# theater history
# tf.Tensor(0.626752479478945, shape=(), dtype=float64) 0.391
# linesituation	isolation	3.88
#
# situation isolation
# tf.Tensor(0.6427197449947961, shape=(), dtype=float64) 0.388
# lineprofit	warning	3.88
#
# profit warning
# tf.Tensor(0.5930323939733593, shape=(), dtype=float64) 0.388
# linemedia	trading	3.88
#
# media trading
# tf.Tensor(0.6083502302653535, shape=(), dtype=float64) 0.388
# linechance	credibility	3.88
#
# chance credibility
# tf.Tensor(0.6453219464696458, shape=(), dtype=float64) 0.388
# lineprecedent	information	3.85
#
# precedent information
# tf.Tensor(0.5672670004187734, shape=(), dtype=float64) 0.385
# linearchitecture	century	3.78
#
# architecture century
# tf.Tensor(0.6704275664845505, shape=(), dtype=float64) 0.378
# linepopulation	development	3.75
#
# population development
# tf.Tensor(0.6277676330823299, shape=(), dtype=float64) 0.375
# linestock	live	3.73
#
# stock live
# tf.Tensor(0.6040238293481345, shape=(), dtype=float64) 0.373
# linepeace	atmosphere	3.69
#
# peace atmosphere
# tf.Tensor(0.5939438915404646, shape=(), dtype=float64) 0.369
# linemorality	marriage	3.69
#
# morality marriage
# tf.Tensor(0.6079210891267641, shape=(), dtype=float64) 0.369
# lineminority	peace	3.69
#
# minority peace
# tf.Tensor(0.5769760792450841, shape=(), dtype=float64) 0.369
# lineatmosphere	landscape	3.69
#
# atmosphere landscape
# tf.Tensor(0.6419269161850284, shape=(), dtype=float64) 0.369
# linereport	gain	3.63
#
# report gain
# tf.Tensor(0.5993795226989579, shape=(), dtype=float64) 0.363
# linemusic	project	3.63
#
# music project
# tf.Tensor(0.6705436260216542, shape=(), dtype=float64) 0.363
# lineseven	series	3.56
#
# seven series
# tf.Tensor(0.693230339935619, shape=(), dtype=float64) 0.356
# lineexperience	music	3.47
#
# experience music
# tf.Tensor(0.6661665720777764, shape=(), dtype=float64) 0.34700000000000003
# lineschool	center	3.44
#
# school center
# tf.Tensor(0.6806390711794954, shape=(), dtype=float64) 0.344
# linefive	month	3.38
#
# five month
# tf.Tensor(0.6893908405032982, shape=(), dtype=float64) 0.33799999999999997
# lineannouncement	production	3.38
#
# announcement production
# tf.Tensor(0.6195807176852187, shape=(), dtype=float64) 0.33799999999999997
# linemorality	importance	3.31
#
# morality importance
# tf.Tensor(0.6436004107063924, shape=(), dtype=float64) 0.331
# linemoney	operation	3.31
#
# money operation
# tf.Tensor(0.611431875904856, shape=(), dtype=float64) 0.331
# linedelay	news	3.31
#
# delay news
# tf.Tensor(0.6028973592206732, shape=(), dtype=float64) 0.331
# linegovernor	interview	3.25
#
# governor interview
# tf.Tensor(0.588913944028953, shape=(), dtype=float64) 0.325
# linepractice	institution	3.19
#
# practice institution
# tf.Tensor(0.6420040551261541, shape=(), dtype=float64) 0.319
# linecentury	nation	3.16
#
# century nation
# tf.Tensor(0.642266578860325, shape=(), dtype=float64) 0.316
# linecoast	forest	3.15
#
# coast forest
# tf.Tensor(0.6363087727836707, shape=(), dtype=float64) 0.315
# lineshore	woodland	3.08
#
# shore woodland
# tf.Tensor(0.6087332229699312, shape=(), dtype=float64) 0.308
# linedrink	car	3.04
#
# drink car
# tf.Tensor(0.6284502395241629, shape=(), dtype=float64) 0.304
# linepresident	medal	3.00
#
# president medal
# tf.Tensor(0.6236603481110969, shape=(), dtype=float64) 0.3
# lineprejudice	recognition	3.00
#
# prejudice recognition
# tf.Tensor(0.586997234234326, shape=(), dtype=float64) 0.3
# lineviewer	serial	2.97
#
# viewer serial
# tf.Tensor(0.6003245383650435, shape=(), dtype=float64) 0.29700000000000004
# linepeace	insurance	2.94
#
# peace insurance
# tf.Tensor(0.5704283379799141, shape=(), dtype=float64) 0.294
# lineMars	water	2.94
#
# Mars water
# 0 0.294
# linemedia	gain	2.88
#
# media gain
# tf.Tensor(0.624149063806015, shape=(), dtype=float64) 0.288
# lineprecedent	cognition	2.81
#
# precedent cognition
# tf.Tensor(0.5412597850928117, shape=(), dtype=float64) 0.281
# lineannouncement	effort	2.75
#
# announcement effort
# tf.Tensor(0.6417033871032205, shape=(), dtype=float64) 0.275
# lineline	insurance	2.69
#
# line insurance
# tf.Tensor(0.5784127285788562, shape=(), dtype=float64) 0.269
# linecrane	implement	2.69
#
# crane implement
# tf.Tensor(0.5784454442957241, shape=(), dtype=float64) 0.269
# linedrink	mother	2.65
#
# drink mother
# tf.Tensor(0.6196907908615605, shape=(), dtype=float64) 0.265
# lineopera	industry	2.63
#
# opera industry
# tf.Tensor(0.5930607070798422, shape=(), dtype=float64) 0.263
# linevolunteer	motto	2.56
#
# volunteer motto
# tf.Tensor(0.6056514171519949, shape=(), dtype=float64) 0.256
# linelisting	proximity	2.56
#
# listing proximity
# tf.Tensor(0.5721675698341881, shape=(), dtype=float64) 0.256
# lineprecedent	collection	2.50
#
# precedent collection
# tf.Tensor(0.5895671780749531, shape=(), dtype=float64) 0.25
# linecup	article	2.40
#
# cup article
# tf.Tensor(0.590852782031065, shape=(), dtype=float64) 0.24
# linesign	recess	2.38
#
# sign recess
# tf.Tensor(0.5814986615198229, shape=(), dtype=float64) 0.238
# lineproblem	airport	2.38
#
# problem airport
# tf.Tensor(0.5780931347408272, shape=(), dtype=float64) 0.238
# linereason	hypertension	2.31
#
# reason hypertension
# tf.Tensor(0.5807538600083272, shape=(), dtype=float64) 0.231
# linedirection	combination	2.25
#
# direction combination
# tf.Tensor(0.664095049920014, shape=(), dtype=float64) 0.225
# lineWednesday	news	2.22
#
# Wednesday news
# 0 0.22200000000000003
# lineglass	magician	2.08
#
# glass magician
# tf.Tensor(0.5691674252443032, shape=(), dtype=float64) 0.20800000000000002
# linecemetery	woodland	2.08
#
# cemetery woodland
# tf.Tensor(0.6277358052002849, shape=(), dtype=float64) 0.20800000000000002
# linepossibility	girl	1.94
#
# possibility girl
# tf.Tensor(0.5963689157222954, shape=(), dtype=float64) 0.194
# linecup	substance	1.92
#
# cup substance
# tf.Tensor(0.5271926685362475, shape=(), dtype=float64) 0.192
# lineforest	graveyard	1.85
#
# forest graveyard
# tf.Tensor(0.5862139220583701, shape=(), dtype=float64) 0.185
# linestock	egg	1.81
#
# stock egg
# tf.Tensor(0.5581009741097056, shape=(), dtype=float64) 0.181
# linemonth	hotel	1.81
#
# month hotel
# tf.Tensor(0.6152741095080289, shape=(), dtype=float64) 0.181
# lineenergy	secretary	1.81
#
# energy secretary
# tf.Tensor(0.6197719533813403, shape=(), dtype=float64) 0.181
# lineprecedent	group	1.77
#
# precedent group
# tf.Tensor(0.5370806088394114, shape=(), dtype=float64) 0.177
# lineproduction	hike	1.75
#
# production hike
# tf.Tensor(0.5295563915619651, shape=(), dtype=float64) 0.175
# linestock	phone	1.62
#
# stock phone
# tf.Tensor(0.5932767111711433, shape=(), dtype=float64) 0.162
# lineholy	sex	1.62
#
# holy sex
# tf.Tensor(0.5674591863710406, shape=(), dtype=float64) 0.162
# linestock	CD	1.31
#
# stock CD
# 0 0.131
# linedrink	ear	1.31
#
# drink ear
# tf.Tensor(0.5566581600560601, shape=(), dtype=float64) 0.131
# linedelay	racism	1.19
#
# delay racism
# tf.Tensor(0.5681982697155132, shape=(), dtype=float64) 0.119
# linestock	life	0.92
#
# stock life
# tf.Tensor(0.6014552400453917, shape=(), dtype=float64) 0.092
# linestock	jaguar	0.92
#
# stock jaguar
# tf.Tensor(0.585583258835161, shape=(), dtype=float64) 0.092
# linemonk	slave	0.92
#
# monk slave
# tf.Tensor(0.614375715343199, shape=(), dtype=float64) 0.092
# linelad	wizard	0.92
#
# lad wizard
# tf.Tensor(0.5958341087673007, shape=(), dtype=float64) 0.092
# linesugar	approach	0.88
#
# sugar approach
# tf.Tensor(0.5701347888814111, shape=(), dtype=float64) 0.088
# linerooster	voyage	0.62
#
# rooster voyage
# tf.Tensor(0.5488305579120385, shape=(), dtype=float64) 0.062
# linenoon	string	0.54
#
# noon string
# tf.Tensor(0.5777798460872383, shape=(), dtype=float64) 0.054000000000000006
# linechord	smile	0.54
#
# chord smile
# tf.Tensor(0.5943291642683316, shape=(), dtype=float64) 0.054000000000000006
# lineprofessor	cucumber	0.31
#
# professor cucumber
# tf.Tensor(0.5342412741473783, shape=(), dtype=float64) 0.031
# lineking	cabbage	0.23
#
# king cabbage
# tf.Tensor(0.5068312560196324, shape=(), dtype=float64) 0.023
# Average Distance between prediction and hand assigned is tf.Tensor(0.2159004821899102, shape=(), dtype=float64)

# %%
from scipy import stats
stats.spearmanr(losses, scores)
# Out:
# SpearmanrResult(correlation=0.6282645902228762, pvalue=1.0846964368661613e-23)
