# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import numpy as np
import tensorflow as tf
path = r'..\\embeddings\\'
id_dict = {}
word_dict = {}

matrix = []
dimensions = 300
with open(path + "base_emb", 'r' , encoding="utf-8")  as f:
    lines = f.readlines()
    vocab_size = len(lines)
    
    matrix = np.zeros((vocab_size,dimensions),dtype=float)
    for line in lines:
        values = line.split()
        word = values[0].strip()
        id = len(id_dict)
        id_dict[word]=id
        word_dict[id] = word
        vector = np.asarray(values[1:], "double")
        matrix[id_dict[word],:] = vector
print(len(id_dict))
# Out:
# 148733

# %%
print(type(word_dict))
# Out:
# <class 'dict'>

# %%
def find_candidate(sim,id_a,id_a_star,id_b):
    myList = [id_a, id_b, id_a_star];
    myList.sort();
    
    if(myList[0] != 0):
        index1 = np.argmax(sim[:myList[0]])
    else:
        index1 = None
    sim2 = sim[myList[0]+1:myList[1]]
    if len(sim2) > 0:
        index2 = np.argmax(sim2)
        index2 +=  myList[0]+1
    else:
        index2 = None
    sim3 = sim[myList[1]+1:myList[2]]
    if len(sim3) > 0:
        index3 = np.argmax(sim3)
        index3 +=  myList[1]+1
    else:
        index3 = None
    if(myList[2]+1 < len(sim)):
        index4 = np.argmax(sim[myList[2]+1:])
        index4 +=  myList[2]+1
    else:
        index4 = None
    myList = [index1, index2, index3,index4];
    values = []
    myList2 = []
    for index in myList:
        if index != None:
            values.append(sim[index])
            myList2.append(index)
    index = myList2[np.argmax(values)]

# %% [markdown]
# ## 3cosAdd

# %%
matrix_normalized = tf.nn.l2_normalize(matrix,axis = 1)
def three_cos_predict_np(a,a_star,b,b_star):
    if( a in id_dict and b in id_dict and a_star in id_dict and b_star in id_dict):
        pass
    else:
        return None
    id_a = id_dict[a]
    id_b = id_dict[b]
    id_a_star = id_dict[a_star]
    id_b_star = id_dict[b_star]#remove this after testing
    weight_a = matrix[id_a,:]
    weight_b = matrix[id_b,:]
    weight_a_star = matrix[id_a_star,:]
    direction = weight_b + ( weight_a_star - weight_a)
    direction /= np.linalg.norm(direction)
    
    sim = tf.tensordot(tf.convert_to_tensor(matrix_normalized),tf.convert_to_tensor(direction),axes = 1)
    
    return word_dict[index]

# %%
import time
startTime = time.time()

print(three_cos_predict_np('small','smaller','weak','weaker'))
print(three_cos_predict_np('big','bigger','small','smaller'))
print(three_cos_predict_np('germany','berlin','france','paris'))
print(three_cos_predict_np('one','two','three','four'))
print(three_cos_predict_np('tall','taller','big','bigger'))

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# strong
# larger
# paris
# four
# showcase
# Execution time in seconds: 0.13303017616271973

# %%
def find_nearest_k(searched_word,k):
    list = []
    id = id_dict[searched_word]
    searched_vector = matrix_normalized[id,:] 
    
    for word in id_dict:
        word_weights = matrix_normalized[id_dict[word]]
        loss = tf.tensordot(word_weights,searched_vector,axes = 1).numpy()
        list = insert(list,(word,loss))
        if len(list) > k:
            list = list[0:k+1]
    return list[0:k]

# Function to insert element
def insert(list, tuple):
    (word,n) = tuple
    if(len(list) == 0):
        list = [(word,n)]
    # Searching for the position
    for i in range(len(list)):
        (word_i,n_i) = list[i]
        if n_i < n:
            index = i
            break
      
    # Inserting n in the list
    list = list[:i] + [(word,n)] + list[i:]
    return list


print(find_nearest_k('smaller',7))#this should produce one, for the same vectors
print(find_nearest_k('computer',7))
# Out:
# [('smaller', 0.9999999999999999), ('larger', 0.7679766195587474), ('small', 0.6711319448786391), ('large', 0.6451574459607814), ('typically', 0.6236010111428973), ('these', 0.6218913987567888), ('contained', 0.620946589633534)]
# [('computer', 1.0000000000000002), ('computers', 0.5085382386991789), ('design', 0.4626533925729936), ('systems', 0.45063344092741375), ('allows', 0.4436976593874406), ('advanced', 0.4278621239165861), ('utilizing', 0.4266367676316634)]

# %%
count_sucess = 0
count_unsucessful = 0
count_out_of_vocab = 0
count_b = 0
with open(r'..\datasets\miklov Analogies.txt') as file:
    lines = file.readlines()
    for index, line in enumerate(lines):
        if(index % 1000 == 0):
            print(str(index) + " of " + str(len(lines)))
            
        if line.startswith(":"):
            pass
        else:
            a,a_star,b,b_star = line.split(" ")
            b_star = b_star.strip()#super important
            
            predicted = three_cos_predict_np(a,a_star,b,b_star)
            print(a,a_star,b,b_star,'=>',predicted)
            if(predicted == None):
                count_out_of_vocab += 1
            elif(predicted == b_star):
                count_sucess += 1
            elif(predicted == b):
                count_b += 1
            else:
                count_unsucessful += 1

print(count_sucess/ len(lines))
print(count_out_of_vocab)
# Out:
# 0 of 13106
# abuja nigeria accra ghana => malaysia
# abuja nigeria algiers algeria => malaysia
# abuja nigeria amman jordan => malaysia
# abuja nigeria ankara turkey => lebanon
# abuja nigeria antananarivo madagascar => subcontinent
# abuja nigeria apia samoa => cyrus
# abuja nigeria ashgabat turkmenistan => vallabh
# abuja nigeria asmara eritrea => ethiopia
# abuja nigeria astana kazakhstan => malaysia
# abuja nigeria athens greece => occupies
# abuja nigeria baghdad iraq => lebanon
# abuja nigeria baku azerbaijan => lebanon
# abuja nigeria bamako mali => implementation
# abuja nigeria bangkok thailand => thereafter
# abuja nigeria banjul gambia => implementation
# abuja nigeria beijing china => tianjin
# abuja nigeria beirut lebanon => lebanon
# abuja nigeria belgrade serbia => lebanon
# abuja nigeria belmopan belize => ethiopia
# abuja nigeria berlin germany => hamburg
# abuja nigeria bern switzerland => lebanon
# abuja nigeria bishkek kyrgyzstan => malaysia
# abuja nigeria bratislava slovakia => nowadays
# abuja nigeria brussels belgium => traveled
# abuja nigeria bucharest romania => romania
# abuja nigeria budapest hungary => unfulfilled
# abuja nigeria bujumbura burundi => ethiopia
# abuja nigeria cairo egypt => mexico
# abuja nigeria canberra australia => subcontinent
# abuja nigeria caracas venezuela => malaysia
# abuja nigeria chisinau moldova => ethiopia
# abuja nigeria conakry guinea => malaysia
# abuja nigeria copenhagen denmark => visited
# abuja nigeria dakar senegal => ghana
# abuja nigeria damascus syria => ethiopia
# abuja nigeria dhaka bangladesh => germany
# abuja nigeria doha qatar => hogan
# abuja nigeria dublin ireland => ireland
# abuja nigeria dushanbe tajikistan => malaysia
# accra ghana algiers algeria => mississippi
# accra ghana amman jordan => mississippi
# accra ghana ankara turkey => russia
# accra ghana antananarivo madagascar => mississippi
# accra ghana apia samoa => mississippi
# accra ghana ashgabat turkmenistan => mississippi
# accra ghana asmara eritrea => athenian
# accra ghana astana kazakhstan => ancestors
# accra ghana athens greece => colorado
# accra ghana baghdad iraq => nigeria
# accra ghana baku azerbaijan => heroes
# accra ghana bamako mali => mississippi
# accra ghana bangkok thailand => northern
# accra ghana banjul gambia => mississippi
# accra ghana beijing china => northern
# accra ghana beirut lebanon => northern
# accra ghana belgrade serbia => headed
# accra ghana belmopan belize => mississippi
# accra ghana berlin germany => munich
# accra ghana bern switzerland => notables
# accra ghana bishkek kyrgyzstan => mississippi
# accra ghana bratislava slovakia => slovakia
# accra ghana brussels belgium => belgium
# accra ghana bucharest romania => romania
# accra ghana budapest hungary => headed
# accra ghana bujumbura burundi => gabon
# accra ghana cairo egypt => northern
# accra ghana canberra australia => maryland
# accra ghana caracas venezuela => rural
# accra ghana chisinau moldova => mississippi
# accra ghana conakry guinea => gabon
# accra ghana copenhagen denmark => mississippi
# accra ghana dakar senegal => gabon
# accra ghana damascus syria => circles
# accra ghana dhaka bangladesh => bengal
# accra ghana doha qatar => kuwait
# accra ghana dublin ireland => ireland
# accra ghana dushanbe tajikistan => mississippi
# accra ghana funafuti tuvalu => vanderbilt
# algiers algeria amman jordan => grassy
# algiers algeria ankara turkey => viewpoint
# algiers algeria antananarivo madagascar => erythematosus
# algiers algeria apia samoa => alai
# algiers algeria ashgabat turkmenistan => autobahn
# algiers algeria asmara eritrea => inclined
# algiers algeria astana kazakhstan => safi
# algiers algeria athens greece => presently
# algiers algeria baghdad iraq => persisted
# algiers algeria baku azerbaijan => cameroon
# algiers algeria bamako mali => autobahn
# algiers algeria bangkok thailand => rink
# algiers algeria banjul gambia => botswana
# algiers algeria beijing china => winter
# algiers algeria beirut lebanon => hamburg
# algiers algeria belgrade serbia => swim
# algiers algeria belmopan belize => pomegranates
# algiers algeria berlin germany => hamburg
# algiers algeria bern switzerland => autobahn
# algiers algeria bishkek kyrgyzstan => autobahn
# algiers algeria bratislava slovakia => recreated
# algiers algeria brussels belgium => indonesia
# algiers algeria bucharest romania => earthquake
# algiers algeria budapest hungary => hamburg
# algiers algeria bujumbura burundi => autobahn
# algiers algeria cairo egypt => colonial
# algiers algeria canberra australia => ontario
# algiers algeria caracas venezuela => indonesia
# algiers algeria chisinau moldova => prakrit
# algiers algeria conakry guinea => persisted
# algiers algeria copenhagen denmark => nowadays
# algiers algeria dakar senegal => unmodified
# algiers algeria damascus syria => ontario
# algiers algeria dhaka bangladesh => ontario
# algiers algeria doha qatar => bonsai
# algiers algeria dublin ireland => ireland
# algiers algeria dushanbe tajikistan => botswana
# algiers algeria funafuti tuvalu => casey
# algiers algeria gaborone botswana => lorestan
# amman jordan ankara turkey => tony
# amman jordan antananarivo madagascar => latvala
# amman jordan apia samoa => h&h
# amman jordan ashgabat turkmenistan => mesh
# amman jordan asmara eritrea => namibian
# amman jordan astana kazakhstan => tony
# amman jordan athens greece => greece
# amman jordan baghdad iraq => captured
# amman jordan baku azerbaijan => hogan
# amman jordan bamako mali => observers
# amman jordan bangkok thailand => respectively
# amman jordan banjul gambia => h&h
# amman jordan beijing china => nanjing
# amman jordan beirut lebanon => locked
# amman jordan belgrade serbia => andrews
# amman jordan belmopan belize => tony
# amman jordan berlin germany => munich
# amman jordan bern switzerland => pleasantville
# amman jordan bishkek kyrgyzstan => mesh
# amman jordan bratislava slovakia => unification
# amman jordan brussels belgium => hogan
# amman jordan bucharest romania => andrews
# amman jordan budapest hungary => hungary
# amman jordan bujumbura burundi => pleasantville
# amman jordan cairo egypt => gets
# amman jordan canberra australia => tony
# amman jordan caracas venezuela => tony
# amman jordan chisinau moldova => tony
# amman jordan conakry guinea => tony
# amman jordan copenhagen denmark => tony
# amman jordan dakar senegal => unification
# amman jordan damascus syria => muslims
# amman jordan dhaka bangladesh => signalling
# amman jordan doha qatar => observers
# amman jordan dublin ireland => ireland
# amman jordan dushanbe tajikistan => campania
# amman jordan funafuti tuvalu => tony
# amman jordan gaborone botswana => tony
# amman jordan georgetown guyana => signalling
# ankara turkey antananarivo madagascar => annexed
# ankara turkey apia samoa => bikers
# ankara turkey ashgabat turkmenistan => pennsylvania
# ankara turkey asmara eritrea => pennsylvania
# ankara turkey astana kazakhstan => scandinavia
# ankara turkey athens greece => greece
# ankara turkey baghdad iraq => pennsylvania
# ankara turkey baku azerbaijan => pennsylvania
# ankara turkey bamako mali => parts
# ankara turkey bangkok thailand => occupied
# ankara turkey banjul gambia => tvo
# ankara turkey beijing china => china
# ankara turkey beirut lebanon => pennsylvania
# ankara turkey belgrade serbia => southeast
# ankara turkey belmopan belize => pennsylvania
# ankara turkey berlin germany => occupied
# ankara turkey bern switzerland => southeast
# ankara turkey bishkek kyrgyzstan => tvo
# ankara turkey bratislava slovakia => spain
# ankara turkey brussels belgium => pennsylvania
# ankara turkey bucharest romania => romania
# ankara turkey budapest hungary => hungary
# ankara turkey bujumbura burundi => scandinavia
# ankara turkey cairo egypt => britain
# ankara turkey canberra australia => pennsylvania
# ankara turkey caracas venezuela => britain
# ankara turkey chisinau moldova => pennsylvania
# ankara turkey conakry guinea => southeast
# ankara turkey copenhagen denmark => visited
# ankara turkey dakar senegal => britain
# ankara turkey damascus syria => hollow
# ankara turkey dhaka bangladesh => pennsylvania
# ankara turkey doha qatar => parts
# ankara turkey dublin ireland => ireland
# ankara turkey dushanbe tajikistan => netherlands
# ankara turkey funafuti tuvalu => southeast
# ankara turkey gaborone botswana => southeast
# ankara turkey georgetown guyana => pennsylvania
# ankara turkey hanoi vietnam => pennsylvania
# antananarivo madagascar apia samoa => tonga
# antananarivo madagascar ashgabat turkmenistan => liberia
# antananarivo madagascar asmara eritrea => seychelles
# antananarivo madagascar astana kazakhstan => plates
# antananarivo madagascar athens greece => 1986
# antananarivo madagascar baghdad iraq => africa
# antananarivo madagascar baku azerbaijan => colombia
# antananarivo madagascar bamako mali => party
# antananarivo madagascar bangkok thailand => wherein
# antananarivo madagascar banjul gambia => africa
# antananarivo madagascar beijing china => 1986
# antananarivo madagascar beirut lebanon => partisans
# antananarivo madagascar belgrade serbia => 1986
# antananarivo madagascar belmopan belize => utah
# antananarivo madagascar berlin germany => munich
# antananarivo madagascar bern switzerland => ciphers
# antananarivo madagascar bishkek kyrgyzstan => coast
# antananarivo madagascar bratislava slovakia => 1986
# antananarivo madagascar brussels belgium => lisbon
# antananarivo madagascar bucharest romania => 1986
# antananarivo madagascar budapest hungary => 1986
# antananarivo madagascar bujumbura burundi => seychelles
# antananarivo madagascar cairo egypt => party
# antananarivo madagascar canberra australia => 1986
# antananarivo madagascar caracas venezuela => 1986
# antananarivo madagascar chisinau moldova => wheat
# antananarivo madagascar conakry guinea => cockroaches
# antananarivo madagascar copenhagen denmark => 1888
# antananarivo madagascar dakar senegal => africa
# antananarivo madagascar damascus syria => kennedy
# antananarivo madagascar dhaka bangladesh => utah
# antananarivo madagascar doha qatar => africa
# antananarivo madagascar dublin ireland => ireland
# antananarivo madagascar dushanbe tajikistan => revolutionized
# antananarivo madagascar funafuti tuvalu => hafez
# antananarivo madagascar gaborone botswana => foreground
# antananarivo madagascar georgetown guyana => revolutionized
# antananarivo madagascar hanoi vietnam => coast
# antananarivo madagascar harare zimbabwe => africa
# apia samoa ashgabat turkmenistan => ignorance
# apia samoa asmara eritrea => bengal
# apia samoa astana kazakhstan => depopulated
# apia samoa athens greece => progressed
# apia samoa baghdad iraq => battling
# apia samoa baku azerbaijan => progressed
# apia samoa bamako mali => niigata
# apia samoa bangkok thailand => hub
# apia samoa banjul gambia => microvax
# apia samoa beijing china => places
# apia samoa beirut lebanon => violent
# apia samoa belgrade serbia => milan
# apia samoa belmopan belize => cpc
# apia samoa berlin germany => tokyo
# apia samoa bern switzerland => kinnikuman
# apia samoa bishkek kyrgyzstan => kazakhstan
# apia samoa bratislava slovakia => progressed
# apia samoa brussels belgium => paris
# apia samoa bucharest romania => zagreb
# apia samoa budapest hungary => progressed
# apia samoa bujumbura burundi => keflavík
# apia samoa cairo egypt => ignorance
# apia samoa canberra australia => brisbane
# apia samoa caracas venezuela => malaysia
# apia samoa chisinau moldova => cpc
# apia samoa conakry guinea => malaysia
# apia samoa copenhagen denmark => progressed
# apia samoa dakar senegal => bethlehem
# apia samoa damascus syria => progressed
# apia samoa dhaka bangladesh => bengal
# apia samoa doha qatar => ignorance
# apia samoa dublin ireland => ireland
# apia samoa dushanbe tajikistan => dewsbury
# apia samoa funafuti tuvalu => fiji
# apia samoa gaborone botswana => fidesz
# apia samoa georgetown guyana => monash
# apia samoa hanoi vietnam => khz
# apia samoa harare zimbabwe => policies
# apia samoa havana cuba => fiji
# ashgabat turkmenistan asmara eritrea => seychelles
# ashgabat turkmenistan astana kazakhstan => uzbekistan
# bangkok thailand gaborone botswana => shillingford
# bangkok thailand georgetown guyana => capped
# bangkok thailand hanoi vietnam => jehol
# bangkok thailand harare zimbabwe => pozsony
# bangkok thailand havana cuba => cuba
# bangkok thailand helsinki finland => chile
# bangkok thailand islamabad pakistan => hoppus
# bangkok thailand jakarta indonesia => indonesia
# bangkok thailand kabul afghanistan => chile
# bangkok thailand kampala uganda => compliance
# bangkok thailand kathmandu nepal => compliance
# bangkok thailand khartoum sudan => chico
# bangkok thailand kiev ukraine => guardianship
# banjul gambia beijing china => china
# banjul gambia beirut lebanon => ix
# banjul gambia belgrade serbia => zagreb
# banjul gambia belmopan belize => dolerite
# banjul gambia berlin germany => munich
# banjul gambia bern switzerland => dummy
# banjul gambia bishkek kyrgyzstan => sexes
# banjul gambia bratislava slovakia => sindh
# banjul gambia brussels belgium => hiding
# banjul gambia bucharest romania => zagreb
# banjul gambia budapest hungary => 1934
# banjul gambia bujumbura burundi => eligius
# banjul gambia cairo egypt => states
# banjul gambia canberra australia => australian
# banjul gambia caracas venezuela => governed
# banjul gambia chisinau moldova => memon
# banjul gambia conakry guinea => tempered
# banjul gambia copenhagen denmark => 1934
# banjul gambia dakar senegal => governed
# banjul gambia damascus syria => metamorphosis
# banjul gambia dhaka bangladesh => halted
# banjul gambia doha qatar => sexes
# banjul gambia dublin ireland => ireland
# banjul gambia dushanbe tajikistan => desai
# banjul gambia funafuti tuvalu => karimov
# banjul gambia gaborone botswana => pakenham
# banjul gambia georgetown guyana => penn
# banjul gambia hanoi vietnam => dolerite
# banjul gambia harare zimbabwe => zaire
# banjul gambia havana cuba => 1914
# banjul gambia helsinki finland => stockholm
# banjul gambia islamabad pakistan => halted
# banjul gambia jakarta indonesia => stockholm
# banjul gambia kabul afghanistan => iraq
# banjul gambia kampala uganda => dolerite
# banjul gambia kathmandu nepal => sindh
# banjul gambia khartoum sudan => refuge
# banjul gambia kiev ukraine => indentured
# banjul gambia kigali rwanda => ata
# beijing china beirut lebanon => partisans
# beijing china belgrade serbia => moreover
# beijing china belmopan belize => masvingo
# beijing china berlin germany => came
# beijing china bern switzerland => luftwaffe
# beijing china bishkek kyrgyzstan => ze
# beijing china bratislava slovakia => sweden
# beijing china brussels belgium => sweden
# beijing china bucharest romania => sweden
# beijing china budapest hungary => leadership
# beijing china bujumbura burundi => provinces
# beijing china cairo egypt => australia
# beijing china canberra australia => australia
# beijing china caracas venezuela => australia
# beijing china chisinau moldova => alpena
# beijing china conakry guinea => methods
# beijing china copenhagen denmark => afghanistan
# beijing china dakar senegal => mariehamn
# beijing china damascus syria => sweden
# beijing china dhaka bangladesh => advance
# beijing china doha qatar => computing
# beijing china dublin ireland => ireland
# beijing china dushanbe tajikistan => radiometric
# beijing china funafuti tuvalu => llobregat
# beijing china gaborone botswana => masvingo
# beijing china georgetown guyana => columbia
# beijing china hanoi vietnam => lunar
# beijing china harare zimbabwe => masvingo
# beijing china havana cuba => origins
# beijing china helsinki finland => sweden
# beijing china islamabad pakistan => sweden
# beijing china jakarta indonesia => cure
# beijing china kabul afghanistan => afghanistan
# beijing china kampala uganda => yellowknife
# beijing china kathmandu nepal => sweden
# beijing china khartoum sudan => principality
# beijing china kiev ukraine => sweden
# beijing china kigali rwanda => provinces
# beijing china kingston jamaica => fell
# beirut lebanon belgrade serbia => besides
# beirut lebanon belmopan belize => castlemaine
# beirut lebanon berlin germany => munich
# beirut lebanon bern switzerland => russians
# beirut lebanon bishkek kyrgyzstan => ourselves
# beirut lebanon bratislava slovakia => sudetenland
# beirut lebanon brussels belgium => charting
# beirut lebanon bucharest romania => budapest
# beirut lebanon budapest hungary => charting
# beirut lebanon bujumbura burundi => xiaoming
# beirut lebanon cairo egypt => mexico
# beirut lebanon canberra australia => charting
# beirut lebanon caracas venezuela => louisiana
# beirut lebanon chisinau moldova => cadwallader
# beirut lebanon conakry guinea => charting
# beirut lebanon copenhagen denmark => afghanistan
# beirut lebanon dakar senegal => negombo
# beirut lebanon damascus syria => iraq
# beirut lebanon dhaka bangladesh => turkey
# beirut lebanon doha qatar => nhra
# beirut lebanon dublin ireland => ireland
# beirut lebanon dushanbe tajikistan => gezira
# beirut lebanon funafuti tuvalu => cadwallader
# beirut lebanon gaborone botswana => inclusiveness
# beirut lebanon georgetown guyana => seminary
# beirut lebanon hanoi vietnam => believing
# beirut lebanon harare zimbabwe => mexico
# beirut lebanon havana cuba => mexico
# beirut lebanon helsinki finland => turkey
# beirut lebanon islamabad pakistan => pakistani
# beirut lebanon jakarta indonesia => charting
# beirut lebanon kabul afghanistan => iraq
# beirut lebanon kampala uganda => cityscape
# beirut lebanon kathmandu nepal => charting
# beirut lebanon khartoum sudan => belonging
# beirut lebanon kiev ukraine => hannibal
# beirut lebanon kigali rwanda => charting
# beirut lebanon kingston jamaica => traveled
# beirut lebanon libreville gabon => leckie
# belgrade serbia belmopan belize => eternia
# belgrade serbia berlin germany => present
# belgrade serbia bern switzerland => maximization
# belgrade serbia bishkek kyrgyzstan => 1994/95
# belgrade serbia bratislava slovakia => nunavut
# belgrade serbia brussels belgium => present
# belgrade serbia bucharest romania => romania
# belgrade serbia budapest hungary => 1928
# belgrade serbia bujumbura burundi => maximization
# belgrade serbia cairo egypt => compte
# belgrade serbia canberra australia => california
# belgrade serbia caracas venezuela => hannigan
# belgrade serbia chisinau moldova => monophysite
# belgrade serbia conakry guinea => vakula
# belgrade serbia copenhagen denmark => describes
# belgrade serbia dakar senegal => viipuri
# belgrade serbia damascus syria => narnia
# belgrade serbia dhaka bangladesh => rawalpindi
# belgrade serbia doha qatar => discretization
# belgrade serbia dublin ireland => ireland
# belgrade serbia dushanbe tajikistan => maximization
# belgrade serbia funafuti tuvalu => monophysite
# belgrade serbia gaborone botswana => countercult
# belgrade serbia georgetown guyana => albanians
# belgrade serbia hanoi vietnam => cabramatta
# belgrade serbia harare zimbabwe => cabramatta
# belgrade serbia havana cuba => tropics
# belgrade serbia helsinki finland => finland
# belgrade serbia islamabad pakistan => rawalpindi
# belgrade serbia jakarta indonesia => instruct
# belgrade serbia kabul afghanistan => godey
# belgrade serbia kampala uganda => rawalpindi
# belgrade serbia kathmandu nepal => linfu
# belgrade serbia khartoum sudan => río
# belgrade serbia kiev ukraine => reformed
# belgrade serbia kigali rwanda => vakula
# belgrade serbia kingston jamaica => reformed
# belgrade serbia libreville gabon => tago
# belgrade serbia lilongwe malawi => diglossia
# belmopan belize berlin germany => 1950
# belmopan belize bern switzerland => thereafter
# belmopan belize bishkek kyrgyzstan => doncaster
# belmopan belize bratislava slovakia => nowadays
# belmopan belize brussels belgium => maintained
# belmopan belize bucharest romania => 1930s
# belmopan belize budapest hungary => focuses
# belmopan belize bujumbura burundi => bhutan
# belmopan belize cairo egypt => additionally
# belmopan belize canberra australia => sydney
# belmopan belize caracas venezuela => sydney
# belmopan belize chisinau moldova => mongolia
# belmopan belize conakry guinea => bound
# belmopan belize copenhagen denmark => nowadays
# belmopan belize dakar senegal => sydney
# belmopan belize damascus syria => begun
# belmopan belize dhaka bangladesh => reorganized
# belmopan belize doha qatar => armor
# belmopan belize dublin ireland => additionally
# belmopan belize dushanbe tajikistan => 1883
# belmopan belize funafuti tuvalu => sydney
# belmopan belize gaborone botswana => bhutan
# belmopan belize georgetown guyana => devised
# belmopan belize hanoi vietnam => acknowledged
# belmopan belize harare zimbabwe => botswana
# belmopan belize havana cuba => bound
# belmopan belize helsinki finland => 1883
# belmopan belize islamabad pakistan => emeritus
# belmopan belize jakarta indonesia => indonesia
# belmopan belize kabul afghanistan => cleared
# belmopan belize kampala uganda => sydney
# belmopan belize kathmandu nepal => banner
# belmopan belize khartoum sudan => firms
# belmopan belize kiev ukraine => 1883
# belmopan belize kigali rwanda => multinational
# belmopan belize kingston jamaica => traveled
# belmopan belize libreville gabon => emeritus
# belmopan belize lilongwe malawi => chongqing
# belmopan belize lima peru => acknowledged
# berlin germany bern switzerland => flee
# berlin germany bishkek kyrgyzstan => drc
# berlin germany bratislava slovakia => funded
# berlin germany brussels belgium => bavaria
# berlin germany bucharest romania => money
# berlin germany budapest hungary => flee
# berlin germany bujumbura burundi => achtung
# berlin germany cairo egypt => residents
# berlin germany canberra australia => australia
# berlin germany caracas venezuela => abroad
# berlin germany chisinau moldova => crore
# berlin germany conakry guinea => pugs
# berlin germany copenhagen denmark => abroad
# berlin germany dakar senegal => usgs
# berlin germany damascus syria => silently
# berlin germany dhaka bangladesh => macclesfield
# berlin germany doha qatar => discretization
# berlin germany dublin ireland => ireland
# berlin germany dushanbe tajikistan => countries
# berlin germany funafuti tuvalu => seeadler
# berlin germany gaborone botswana => burkina
# berlin germany georgetown guyana => penn
# berlin germany hanoi vietnam => bavaria
# berlin germany harare zimbabwe => matabeleland
# berlin germany havana cuba => countries
# berlin germany helsinki finland => abroad
# berlin germany islamabad pakistan => stockwell
# berlin germany jakarta indonesia => ossetia
# berlin germany kabul afghanistan => cyprus
# berlin germany kampala uganda => innervate
# berlin germany kathmandu nepal => bavaria
# berlin germany khartoum sudan => money
# berlin germany kiev ukraine => whitchurch
# berlin germany kigali rwanda => drc
# berlin germany kingston jamaica => met
# berlin germany libreville gabon => boxer
# berlin germany lilongwe malawi => lactose
# berlin germany lima peru => bavaria
# berlin germany lisbon portugal => portugal
# bern switzerland bishkek kyrgyzstan => namibia
# bern switzerland bratislava slovakia => colombia
# bern switzerland brussels belgium => belgium
# bern switzerland bucharest romania => 1923
# bern switzerland budapest hungary => colombia
# bern switzerland bujumbura burundi => sparling
# bern switzerland cairo egypt => thailand
# bern switzerland canberra australia => belgium
# bern switzerland caracas venezuela => thailand
# bern switzerland chisinau moldova => bikram
# bern switzerland conakry guinea => namibia
# bern switzerland copenhagen denmark => denmark
# bern switzerland dakar senegal => colombia
# bern switzerland damascus syria => thailand
# bern switzerland dhaka bangladesh => namibia
# bern switzerland doha qatar => colombia
# bern switzerland dublin ireland => ireland
# bern switzerland dushanbe tajikistan => schenker
# bern switzerland funafuti tuvalu => appeal
# bern switzerland gaborone botswana => namibia
# bern switzerland georgetown guyana => columbia
# bern switzerland hanoi vietnam => antrim
# bern switzerland harare zimbabwe => namibia
# bern switzerland havana cuba => colombia
# bern switzerland helsinki finland => finland
# bern switzerland islamabad pakistan => namibia
# bern switzerland jakarta indonesia => thailand
# bern switzerland kabul afghanistan => belonged
# bern switzerland kampala uganda => thailand
# bern switzerland kathmandu nepal => thailand
# bern switzerland khartoum sudan => greece
# bern switzerland kiev ukraine => belgium
# bern switzerland kigali rwanda => windhoek
# bern switzerland kingston jamaica => columbia
# bern switzerland libreville gabon => rozen
# bern switzerland lilongwe malawi => namibia
# bern switzerland lima peru => 1986
# bern switzerland lisbon portugal => renewed
# bern switzerland ljubljana slovenia => colombia
# bishkek kyrgyzstan bratislava slovakia => nowadays
# bishkek kyrgyzstan brussels belgium => belgium
# bishkek kyrgyzstan bucharest romania => parma
# bishkek kyrgyzstan budapest hungary => belgrade
# bishkek kyrgyzstan bujumbura burundi => opportunism
# bishkek kyrgyzstan cairo egypt => turkmenistan
# bishkek kyrgyzstan canberra australia => stephen
# bishkek kyrgyzstan caracas venezuela => turkmenistan
# bishkek kyrgyzstan chisinau moldova => pistoia
# bishkek kyrgyzstan conakry guinea => accounting
# bishkek kyrgyzstan copenhagen denmark => n.
# bishkek kyrgyzstan dakar senegal => villers
# bishkek kyrgyzstan damascus syria => circles
# bishkek kyrgyzstan dhaka bangladesh => n.
# bishkek kyrgyzstan doha qatar => 160
# bishkek kyrgyzstan dublin ireland => ireland
# bishkek kyrgyzstan dushanbe tajikistan => turkmenistan
# bishkek kyrgyzstan funafuti tuvalu => pistoia
# bishkek kyrgyzstan gaborone botswana => turkmenistan
# bishkek kyrgyzstan georgetown guyana => occidental
# bishkek kyrgyzstan hanoi vietnam => occidental
# bishkek kyrgyzstan harare zimbabwe => bulawayo
# bishkek kyrgyzstan havana cuba => seas
# bishkek kyrgyzstan helsinki finland => 1952
# bishkek kyrgyzstan islamabad pakistan => lahore
# bishkek kyrgyzstan jakarta indonesia => islam
# bishkek kyrgyzstan kabul afghanistan => afghanistan
# bishkek kyrgyzstan kampala uganda => turkmenistan
# bishkek kyrgyzstan kathmandu nepal => seas
# bishkek kyrgyzstan khartoum sudan => exmouth
# bishkek kyrgyzstan kiev ukraine => goguryeo
# bishkek kyrgyzstan kigali rwanda => turkmenistan
# bishkek kyrgyzstan kingston jamaica => extensively
# bishkek kyrgyzstan libreville gabon => buslines
# bishkek kyrgyzstan lilongwe malawi => abbas
# bishkek kyrgyzstan lima peru => n.
# bishkek kyrgyzstan lisbon portugal => portugal
# bishkek kyrgyzstan ljubljana slovenia => presidium
# bishkek kyrgyzstan london england => entered
# bratislava slovakia brussels belgium => belgium
# bratislava slovakia bucharest romania => romania
# bratislava slovakia budapest hungary => spared
# bratislava slovakia bujumbura burundi => slovenia
# bratislava slovakia cairo egypt => northern
# bratislava slovakia canberra australia => belgium
# bratislava slovakia caracas venezuela => slovenia
# bratislava slovakia chisinau moldova => slovenia
# bratislava slovakia conakry guinea => slovenia
# bratislava slovakia copenhagen denmark => chapel
# bratislava slovakia dakar senegal => slovenia
# bratislava slovakia damascus syria => ethiopia
# bratislava slovakia dhaka bangladesh => bangladesh
# bratislava slovakia doha qatar => sudan
# bratislava slovakia dublin ireland => ireland
# bratislava slovakia dushanbe tajikistan => slovenia
# bratislava slovakia funafuti tuvalu => hockeyallsvenskan
# bratislava slovakia gaborone botswana => aah
# bratislava slovakia georgetown guyana => romagna
# bratislava slovakia hanoi vietnam => perished
# bratislava slovakia harare zimbabwe => slovenia
# bratislava slovakia havana cuba => slovenia
# bratislava slovakia helsinki finland => finland
# bratislava slovakia islamabad pakistan => commune
# bratislava slovakia jakarta indonesia => commune
# bratislava slovakia kabul afghanistan => iraq
# bratislava slovakia kampala uganda => caitanya
# bratislava slovakia kathmandu nepal => slovenia
# bratislava slovakia khartoum sudan => estudio
# bratislava slovakia kiev ukraine => romagna
# bratislava slovakia kigali rwanda => flapped
# bratislava slovakia kingston jamaica => spared
# bratislava slovakia libreville gabon => spared
# bratislava slovakia lilongwe malawi => gaborone
# bratislava slovakia lima peru => argentina
# bratislava slovakia lisbon portugal => slovenia
# bratislava slovakia ljubljana slovenia => sarajevo
# bratislava slovakia london england => residence
# bratislava slovakia luanda angola => slovenia
# brussels belgium bucharest romania => latin
# brussels belgium budapest hungary => hungary
# brussels belgium bujumbura burundi => 96,000
# brussels belgium cairo egypt => australia
# brussels belgium canberra australia => australia
# brussels belgium caracas venezuela => venezuela
# brussels belgium chisinau moldova => 96,000
# brussels belgium conakry guinea => localization
# brussels belgium copenhagen denmark => connecticut
# brussels belgium dakar senegal => australia
# brussels belgium damascus syria => peoples
# brussels belgium dhaka bangladesh => bangladesh
# brussels belgium doha qatar => australia
# brussels belgium dublin ireland => ireland
# brussels belgium dushanbe tajikistan => checkpoint
# brussels belgium funafuti tuvalu => kampar
# brussels belgium gaborone botswana => kampar
# brussels belgium georgetown guyana => evesham
# brussels belgium hanoi vietnam => australia
# brussels belgium harare zimbabwe => zimbabwe
# brussels belgium havana cuba => australia
# brussels belgium helsinki finland => greece
# brussels belgium islamabad pakistan => lahore
# brussels belgium jakarta indonesia => australia
# brussels belgium kabul afghanistan => ruled
# brussels belgium kampala uganda => checkpoint
# brussels belgium kathmandu nepal => poland
# brussels belgium khartoum sudan => australia
# brussels belgium kiev ukraine => rt
# brussels belgium kigali rwanda => 96,000
# brussels belgium kingston jamaica => australia
# brussels belgium libreville gabon => rt
# brussels belgium lilongwe malawi => kampar
# brussels belgium lima peru => crores
# brussels belgium lisbon portugal => australia
# brussels belgium ljubljana slovenia => pns
# brussels belgium london england => australia
# brussels belgium luanda angola => australia
# brussels belgium lusaka zambia => checkpoint
# bucharest romania budapest hungary => entire
# bucharest romania bujumbura burundi => sarastro
# bucharest romania cairo egypt => syria
# bucharest romania canberra australia => australia
# bucharest romania caracas venezuela => rico
# bucharest romania chisinau moldova => criticising
# bucharest romania conakry guinea => criticising
# bucharest romania copenhagen denmark => denmark
# bucharest romania dakar senegal => test
# bucharest romania damascus syria => syria
# bucharest romania dhaka bangladesh => turkey
# bucharest romania doha qatar => criticising
# bucharest romania dublin ireland => ireland
# bucharest romania dushanbe tajikistan => herzegovina
# bucharest romania funafuti tuvalu => naypyidaw
# bucharest romania gaborone botswana => criticising
# bucharest romania georgetown guyana => villanova
# bucharest romania hanoi vietnam => river
# bucharest romania harare zimbabwe => philippine
# bucharest romania havana cuba => spain
# bucharest romania helsinki finland => finland
# bucharest romania islamabad pakistan => cerezo
# bucharest romania jakarta indonesia => criticising
# bucharest romania kabul afghanistan => transylvania
# 1000 of 13106
# bucharest romania kampala uganda => mlas
# bucharest romania kathmandu nepal => criticising
# bucharest romania khartoum sudan => refuge
# bucharest romania kiev ukraine => blind
# bucharest romania kigali rwanda => gulf
# bucharest romania kingston jamaica => inquisition
# bucharest romania libreville gabon => bhutto
# bucharest romania lilongwe malawi => milagros
# bucharest romania lima peru => inquisition
# bucharest romania lisbon portugal => portugal
# bucharest romania ljubljana slovenia => yugoslavia
# bucharest romania london england => serving
# bucharest romania luanda angola => eide
# bucharest romania lusaka zambia => milagros
# bucharest romania madrid spain => spain
# budapest hungary bujumbura burundi => luxembourg
# budapest hungary cairo egypt => represented
# budapest hungary canberra australia => belgium
# budapest hungary caracas venezuela => sat
# budapest hungary chisinau moldova => luxembourg
# budapest hungary conakry guinea => contradict
# budapest hungary copenhagen denmark => luxembourg
# budapest hungary dakar senegal => bulgaria
# budapest hungary damascus syria => russia
# budapest hungary dhaka bangladesh => turkey
# budapest hungary doha qatar => participating
# budapest hungary dublin ireland => ireland
# budapest hungary dushanbe tajikistan => hickam
# budapest hungary funafuti tuvalu => danang
# budapest hungary gaborone botswana => sat
# budapest hungary georgetown guyana => membranes
# budapest hungary hanoi vietnam => sat
# cheerful cheerfully swift swiftly => pna
# cheerful cheerfully typical typically => many
# cheerful cheerfully unfortunate unfortunately => theorised
# cheerful cheerfully usual usually => information
# cheerful cheerfully amazing amazingly => marathon
# cheerful cheerfully apparent apparently => theorised
# cheerful cheerfully calm calmly => locked
# complete completely efficient efficiently => severely
# complete completely fortunate fortunately => quite
# complete completely free freely => directly
# complete completely furious furiously => severely
# complete completely happy happily => looked
# complete completely immediate immediately => gradually
# complete completely infrequent infrequently => confused
# complete completely lucky luckily => pretending
# complete completely most mostly => often
# complete completely obvious obviously => gradually
# complete completely occasional occasionally => occasionally
# complete completely possible possibly => directly
# complete completely precise precisely => properly
# complete completely professional professionally => newly
# complete completely quick quickly => slowly
# complete completely quiet quietly => looked
# complete completely rapid rapidly => severely
# complete completely rare rarely => quite
# complete completely reluctant reluctantly => quickly
# complete completely safe safely => quickly
# complete completely serious seriously => quite
# complete completely slow slowly => partially
# complete completely sudden suddenly => gradually
# complete completely swift swiftly => partially
# complete completely typical typically => sometimes
# complete completely unfortunate unfortunately => rumored
# complete completely usual usually => partially
# complete completely amazing amazingly => confused
# complete completely apparent apparently => gradually
# complete completely calm calmly => gradually
# complete completely cheerful cheerfully => partially
# efficient efficiently fortunate fortunately => felt
# efficient efficiently free freely => choose
# efficient efficiently furious furiously => repaired
# efficient efficiently happy happily => saying
# efficient efficiently immediate immediately => expecting
# efficient efficiently infrequent infrequently => repaired
# efficient efficiently lucky luckily => pretending
# efficient efficiently most mostly => more
# efficient efficiently obvious obviously => tends
# efficient efficiently occasional occasionally => occasionally
# efficient efficiently possible possibly => tends
# efficient efficiently precise precisely => suggestion
# efficient efficiently professional professionally => amateur
# efficient efficiently quick quickly => slowly
# efficient efficiently quiet quietly => repaired
# efficient efficiently rapid rapidly => trains
# efficient efficiently rare rarely => rarely
# efficient efficiently reluctant reluctantly => refusing
# efficient efficiently safe safely => felt
# efficient efficiently serious seriously => encountered
# efficient efficiently slow slowly => slowly
# efficient efficiently sudden suddenly => narrowly
# efficient efficiently swift swiftly => fanned
# efficient efficiently typical typically => tends
# efficient efficiently unfortunate unfortunately => rumored
# efficient efficiently usual usually => merely
# efficient efficiently amazing amazingly => proves
# efficient efficiently apparent apparently => felt
# efficient efficiently calm calmly => slowly
# efficient efficiently cheerful cheerfully => disappears
# efficient efficiently complete completely => episodes
# fortunate fortunately free freely => going
# fortunate fortunately furious furiously => leaving
# fortunate fortunately happy happily => ends
# fortunate fortunately immediate immediately => request
# fortunate fortunately infrequent infrequently => frequent
# fortunate fortunately lucky luckily => weeks
# fortunate fortunately most mostly => many
# fortunate fortunately obvious obviously => contact
# fortunate fortunately occasional occasionally => occasionally
# fortunate fortunately possible possibly => any
# fortunate fortunately precise precisely => discovering
# fortunate fortunately professional professionally => former
# fortunate fortunately quick quickly => taking
# fortunate fortunately quiet quietly => venue
# fortunate fortunately rapid rapidly => contact
# fortunate fortunately rare rarely => missing
# fortunate fortunately reluctant reluctantly => stay
# fortunate fortunately safe safely => build
# fortunate fortunately serious seriously => despite
# fortunate fortunately slow slowly => fast
# fortunate fortunately sudden suddenly => resulting
# fortunate fortunately swift swiftly => noaa
# fortunate fortunately typical typically => contact
# fortunate fortunately unfortunate unfortunately => misfortune
# fortunate fortunately usual usually => contact
# fortunate fortunately amazing amazingly => astonishing
# fortunate fortunately apparent apparently => contact
# fortunate fortunately calm calmly => rises
# fortunate fortunately cheerful cheerfully => highlight
# fortunate fortunately complete completely => another
# fortunate fortunately efficient efficiently => market
# free freely furious furiously => sleeps
# free freely happy happily => murdering
# free freely immediate immediately => accidentally
# free freely infrequent infrequently => glosses
# free freely lucky luckily => sampson
# free freely most mostly => particularly
# free freely obvious obviously => nonetheless
# free freely occasional occasionally => occasionally
# free freely possible possibly => yet
# free freely precise precisely => manipulations
# free freely professional professionally => fascinated
# free freely quick quickly => meditation
# free freely quiet quietly => accidentally
# free freely rapid rapidly => clashes
# free freely rare rarely => cleared
# free freely reluctant reluctantly => fascinated
# free freely safe safely => cleared
# free freely serious seriously => encountered
# free freely slow slowly => accidentally
# free freely sudden suddenly => biologists
# free freely swift swiftly => resveratrol
# free freely typical typically => critic
# free freely unfortunate unfortunately => chitons
# free freely usual usually => accidentally
# free freely amazing amazingly => remarkable
# free freely apparent apparently => possibility
# free freely calm calmly => flawed
# free freely cheerful cheerfully => nettie
# free freely complete completely => departure
# free freely efficient efficiently => perfectly
# free freely fortunate fortunately => skillfully
# furious furiously happy happily => desperately
# furious furiously immediate immediately => overseas
# furious furiously infrequent infrequently => accumulate
# furious furiously lucky luckily => miming
# furious furiously most mostly => many
# furious furiously obvious obviously => suggest
# furious furiously occasional occasionally => numerology
# furious furiously possible possibly => certain
# furious furiously precise precisely => instructing
# furious furiously professional professionally => american
# furious furiously quick quickly => reinstatement
# furious furiously quiet quietly => meditative
# furious furiously rapid rapidly => urbanization
# furious furiously rare rarely => consisting
# furious furiously reluctant reluctantly => able
# furious furiously safe safely => provide
# furious furiously serious seriously => initial
# furious furiously slow slowly => difficult
# furious furiously sudden suddenly => unexpected
# furious furiously swift swiftly => tokoroa
# furious furiously typical typically => important
# furious furiously unfortunate unfortunately => hemsley
# furious furiously usual usually => settling
# furious furiously amazing amazingly => yamagata
# furious furiously apparent apparently => insufficient
# furious furiously calm calmly => accumulate
# furious furiously cheerful cheerfully => polite
# furious furiously complete completely => initial
# furious furiously efficient efficiently => accumulate
# furious furiously fortunate fortunately => monferrato
# furious furiously free freely => available
# happy happily immediate immediately => obtained
# happy happily infrequent infrequently => uncertainties
# happy happily lucky luckily => reluctant
# happy happily most mostly => many
# happy happily obvious obviously => drastically
# happy happily occasional occasionally => concluded
# happy happily possible possibly => further
# happy happily precise precisely => concluded
# happy happily professional professionally => amateur
# happy happily quick quickly => saipan
# happy happily quiet quietly => heartedly
# happy happily rapid rapidly => further
# happy happily rare rarely => identified
# happy happily reluctant reluctantly => sadly
# happy happily safe safely => sadly
# happy happily serious seriously => arguing
# happy happily slow slowly => eastward
# happy happily sudden suddenly => uncertainties
# happy happily swift swiftly => disagrees
# happy happily typical typically => important
# happy happily unfortunate unfortunately => sadly
# happy happily usual usually => concluded
# happy happily amazing amazingly => participates
# happy happily apparent apparently => limitations
# happy happily calm calmly => drastically
# happy happily cheerful cheerfully => disappears
# happy happily complete completely => obtained
# happy happily efficient efficiently => concluded
# happy happily fortunate fortunately => emphasize
# happy happily free freely => concluded
# happy happily furious furiously => concluded
# immediate immediately infrequent infrequently => observing
# immediate immediately lucky luckily => again
# immediate immediately most mostly => though
# immediate immediately obvious obviously => always
# immediate immediately occasional occasionally => frequently
# immediate immediately possible possibly => could
# immediate immediately precise precisely => always
# immediate immediately professional professionally => currently
# immediate immediately quick quickly => getting
# immediate immediately quiet quietly => quickly
# immediate immediately rapid rapidly => again
# immediate immediately rare rarely => always
# immediate immediately reluctant reluctantly => everyone
# immediate immediately safe safely => quickly
# immediate immediately serious seriously => always
# immediate immediately slow slowly => quickly
# immediate immediately sudden suddenly => again
# immediate immediately swift swiftly => finds
# immediate immediately typical typically => usually
# immediate immediately unfortunate unfortunately => carefully
# immediate immediately usual usually => always
# immediate immediately amazing amazingly => never
# immediate immediately apparent apparently => again
# immediate immediately calm calmly => quickly
# immediate immediately cheerful cheerfully => always
# immediate immediately complete completely => beginning
# immediate immediately efficient efficiently => always
# immediate immediately fortunate fortunately => really
# immediate immediately free freely => going
# immediate immediately furious furiously => finally
# immediate immediately happy happily => everyone
# infrequent infrequently lucky luckily => pretending
# infrequent infrequently most mostly => many
# infrequent infrequently obvious obviously => resembles
# infrequent infrequently occasional occasionally => occasionally
# infrequent infrequently possible possibly => thus
# infrequent infrequently precise precisely => resembles
# infrequent infrequently professional professionally => successful
# infrequent infrequently quick quickly => slowly
# infrequent infrequently quiet quietly => resembles
# infrequent infrequently rapid rapidly => clash
# infrequent infrequently rare rarely => looks
# infrequent infrequently reluctant reluctantly => need
# infrequent infrequently safe safely => nonetheless
# infrequent infrequently serious seriously => occasionally
# infrequent infrequently slow slowly => useful
# infrequent infrequently sudden suddenly => phrase
# infrequent infrequently swift swiftly => thriving
# infrequent infrequently typical typically => traditional
# infrequent infrequently unfortunate unfortunately => resembles
# infrequent infrequently usual usually => thus
# infrequent infrequently amazing amazingly => marathon
# infrequent infrequently apparent apparently => consider
# infrequent infrequently calm calmly => merely
# infrequent infrequently cheerful cheerfully => resembles
# infrequent infrequently complete completely => thus
# infrequent infrequently efficient efficiently => better
# infrequent infrequently fortunate fortunately => doubly
# infrequent infrequently free freely => addition
# infrequent infrequently furious furiously => believes
# infrequent infrequently happy happily => easy
# infrequent infrequently immediate immediately => possibly
# lucky luckily most mostly => many
# lucky luckily obvious obviously => doubted
# lucky luckily occasional occasionally => doubted
# lucky luckily possible possibly => follow
# lucky luckily precise precisely => doubted
# lucky luckily professional professionally => involving
# lucky luckily quick quickly => switching
# lucky luckily quiet quietly => maharastra
# lucky luckily rapid rapidly => deterioration
# lucky luckily rare rarely => related
# lucky luckily reluctant reluctantly => doubted
# lucky luckily safe safely => care
# lucky luckily serious seriously => suffered
# lucky luckily slow slowly => facilitated
# lucky luckily sudden suddenly => climbing
# lucky luckily swift swiftly => r.j.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d379845a1a98> in <module>
#      15             b_star = b_star.strip()#super important
#      16
# ---> 17             predicted = three_cos_predict_np(a,a_star,b,b_star)
#      18             print(a,a_star,b,b_star,'=>',predicted)
#      19             if(predicted == None):
#
# <ipython-input-4-6dbe845c38fc> in three_cos_predict_np(a, a_star, b, b_star)
#      15     direction /= np.linalg.norm(direction)
#      16
# ---> 17     sim = tf.tensordot(tf.convert_to_tensor(matrix_normalized),tf.convert_to_tensor(direction),axes = 1)
#      18     myList = [id_a, id_b, id_a_star];
#      19     myList.sort();
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\math_ops.py in tensordot(a, b, axes, name)
#    4800     b_reshape, b_free_dims, b_free_dims_static = _tensordot_reshape(
#    4801         b, b_axes, True)
# -> 4802     ab_matmul = matmul(a_reshape, b_reshape)
#    4803     if isinstance(a_free_dims, list) and isinstance(b_free_dims, list):
#    4804       if (ab_matmul.get_shape().is_fully_defined() and
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    3487       return ret
#    3488     else:
# -> 3489       return gen_math_ops.mat_mul(
#    3490           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    3491
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5692   if tld.is_eager:
#    5693     try:
# -> 5694       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    5695         _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    5696         transpose_b)
#
# KeyboardInterrupt:

# %%
8870 / 13106
# Out:
# 0.6767892568289333

# %%
import winsound
winsound.Beep(440, 500)

# %% [markdown]
# normalised before exclude

# %%
def three_cos_predict_np_norm(a,a_star,b,b_star):
    if( a in id_dict and b in id_dict and a_star in id_dict and b_star in id_dict):
        pass
    else:
        return None
    id_a = id_dict[a]
    id_b = id_dict[b]
    id_a_star = id_dict[a_star]
    id_b_star = id_dict[b_star]#remove this after testing
    weight_a = matrix_normalized[id_a,:]
    weight_b = matrix_normalized[id_b,:]
    weight_a_star = matrix_normalized[id_a_star,:]
    direction = weight_b + ( weight_a_star - weight_a)
    direction /= np.linalg.norm(direction)
    
    sim = tf.tensordot(tf.convert_to_tensor(matrix_normalized),tf.convert_to_tensor(direction),axes = 1)
    myList = [id_a, id_b, id_a_star];
    myList.sort();
    index1 = np.argmax(sim[:myList[0]])
    sim2 = sim[myList[0]+1:myList[1]]
    if len(sim2) > 0:
        index2 = np.argmax(sim[myList[0]+1:myList[1]])
        index2 +=  myList[0]+1
    else:
        index2 = None
    sim3 = sim[myList[1]+1:myList[2]]
    if len(sim3) > 0:
        index3 = np.argmax(sim[myList[1]+1:myList[2]])
        index3 +=  myList[1]+1
    else:
        index3 = None
    index4 = np.argmax(sim[myList[2]+1:])
    index4 +=  myList[2]+1
    
    myList = [index1, index2, index3,index4];
    values = []
    myList2 = []
    for index in myList:
        if index != None:
            values.append(sim[index])
            myList2.append(index)
    index = myList2[np.argmax(values)]
    
    return word_dict[index]

# %%
count_sucess = 0
count_unsucessful = 0
count_out_of_vocab = 0
count_b = 0
with open(r'..\datasets\miklov Analogies.txt') as file:
    lines = file.readlines()
    for index, line in enumerate(lines):
        if(index % 1000 == 0):
            print(str(index) + " of " + str(len(lines)))
            
        if line.startswith(":"):
            pass
        else:
            a,a_star,b,b_star = line.split(" ")
            b_star = b_star.strip()#super important
            
            predicted = three_cos_predict_np_norm(a,a_star,b,b_star)
            if(predicted == None):
                count_out_of_vocab += 1
            elif(predicted == b_star):
                count_sucess += 1
            elif(predicted == b):
                count_b += 1
            else:
                count_unsucessful += 1

print(count_sucess/ len(lines))
print(count_out_of_vocab)

# %% [markdown]
# ## 3cos Mult

# %%
def sim_01(matrix,weight):
    tmp = tf.tensordot(matrix,weight,axes=1)
    tmp = (tmp+1)/2.0
    return tmp

def predict_three_cos_mult(a,a_star,b,b_star):
    if( a in id_dict and b in id_dict and a_star in id_dict and b_star in id_dict):
        pass
    else:
        return None
    
    id_a = id_dict[a]
    id_b = id_dict[b]
    id_a_star = id_dict[a_star]
    
    weight_a = matrix_normalized[id_a,:]
    weight_b = matrix_normalized[id_b,:]
    weight_a_star = matrix_normalized[id_a_star,:]
    
    nominator = sim_01(matrix_normalized,weight_a_star)
    
    nominator = nominator * sim_01(matrix_normalized,weight_b) 
    donominator = sim_01(matrix_normalized,weight_a) + 0.0001
    sim = nominator / donominator
    myList = [id_a, id_b, id_a_star];
    myList.sort();
    index1 = np.argmax(sim[:myList[0]])
    sim2 = sim[myList[0]+1:myList[1]]
    if len(sim2) > 0:
        index2 = np.argmax(sim[myList[0]+1:myList[1]])
        index2 +=  myList[0]+1
    else:
        index2 = None
    sim3 = sim[myList[1]+1:myList[2]]
    if len(sim3) > 0:
        index3 = np.argmax(sim[myList[1]+1:myList[2]])
        index3 +=  myList[1]+1
    else:
        index3 = None
    index4 = np.argmax(sim[myList[2]+1:])
    index4 +=  myList[2]+1
    
    myList = [index1, index2, index3,index4];
    values = []
    myList2 = []
    for index in myList:
        if index != None:
            values.append(sim[index])
            myList2.append(index)
    index = myList2[np.argmax(values)]
    
    return word_dict[index]

# %%
import time
startTime = time.time()

print(predict_three_cos_mult('small','smaller','weak','weaker'))
print(predict_three_cos_mult('big','bigger','small','smaller'))
print(predict_three_cos_mult('germany','berlin','france','paris'))
print(predict_three_cos_mult('one','two','three','four'))

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# %%
count_sucess = 0
count_unsucessful = 0
count_out_of_vocab = 0
with open(r'..\datasets\miklov Analogies.txt') as file:
    lines = file.readlines()
    for index, line in enumerate(lines):
        if(index % 100 == 0):
            print(str(index) + " of " + str(len(lines)) +" => "+str( count_sucess))
            
        if line.startswith(":"):
            pass
        else:
            a,a_star,b,b_star = line.split(" ")
            b_star = b_star.strip()#super important
            
            predicted = predict_three_cos_mult(a,a_star,b,b_star)
            if(predicted == None):
                count_out_of_vocab += 1
            elif(predicted == b_star):
                count_sucess += 1
            else:
                count_unsucessful += 1
print(print(count_sucess/ len(lines)))
print(count_out_of_vocab)

# %%
import winsound
winsound.Beep(440, 500)
