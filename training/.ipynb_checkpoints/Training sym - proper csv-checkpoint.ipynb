# %%
import gensim.downloader as api
#dataset = api.load("text8")
import math
import numpy as np
import h5py
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
import sys
sys.path.append("..")
import tensorflow as tf
from Vocabulary import *
import time
tf.keras.backend.clear_session()
import csv
import cloudpickle
from csv_writer import *

# %%
class lr_On_plato:
    lowest_loss = -1
    lowest_time = 0
    patience = 10
    factor = 0.005
    
    def notify_loss(self,loss,epoch):
        if(self.lowest_loss == -1):
            self.lowest_loss = loss
            self.lowest_time = epoch
        if(loss < self.lowest_loss):
            self.lowest_loss = loss
            self.lowest_time = epoch
        if(loss > self.lowest_loss and self.lowest_time + 10 < epoch):
            self.lowest_loss = loss
            self.lowest_time = epoch
            print("decreased LR")
            self.factor = self.factor * 0.5
    
    def get_lr(self,epoch):
        return self.factor

# %%
class ModelTrainer:
    def __init__(self,vocab_length,block_path,vector_size = 300):
        self.vector_size = vector_size
        # AND HERE IT IS AGAIN
        self.block_length = 20000
        self.amount_split = math.ceil(vocab_length/float(self.block_length))
        print('amout_split: ' + str(self.amount_split))
        self.block_path = block_path
        self.vocab_length = vocab_length
    
    #start training for first time
    def prepare(self,filename):
        self.f = h5py.File('S:\\{filename}.hdf5'.format(filename=filename), "w")#plus experiment name
        #initalize all the HDF files
        self.con_weights = self.f.create_dataset("context-weights", (self.vocab_length, self.vector_size))
        self.weights = self.f.create_dataset("weights",(self.vector_size,self.vocab_length))
        self.context_bias = self.f.create_dataset("context-bias", (self.vocab_length,1))
        self.bias = self.f.create_dataset("bias", (1,self.vocab_length))
        self.csv_writer = CSV_writer(filename+".csv")

        self.init_matrices()
    
    #return to training
    def resume(self,filename):
        self.f = h5py.File('S:\\{filename}.hdf5'.format(filename=filename), "r+")#plus experiment name
        #initalize all the HDF files
        self.con_weights = self.f.get("context-weights")
        self.weights = self.f.get("weights")
        self.context_bias = self.f.get("context-bias")
        self.bias = self.f.get("bias")
        self.csv_writer = CSV_writer(filename+".csv",appendmode=True)

    
    def init_matrices(self,chunk_size=10000):
        self.init_hdf_matrix(self.weights,-0.5,0.5,chunk_size)
        self.init_hdf_matrix(self.con_weights,-0.5,0.5,chunk_size)
        self.init_hdf_matrix(self.context_bias,-0.5,0.5,chunk_size)
        self.init_hdf_matrix(self.bias,-0.5,0.5,chunk_size)
    
    def init_hdf_matrix(self,hdf_data,min_value,max_value,block_length):
        if len(hdf_data) > len(hdf_data[0]):
            iterations = int(math.ceil(len(hdf_data) / float(block_length)))
            for i in range(iterations):
                current_size = min(block_length,len(hdf_data)-block_length*i)
                hdf_data[i*block_length:(i+1)*block_length , :] = np.random.rand(current_size,len(hdf_data[0]))/self.vector_size
        else:
            iterations = int(math.ceil(len(hdf_data[0]) / float(block_length)))
            for i in range(iterations):
                current_size = min(block_length,len(hdf_data[0])-block_length*i)
                hdf_data[:,i*block_length:(i+1)*block_length] = np.random.rand(len(hdf_data),current_size)/self.vector_size
            
    
    def load_blocks(self,zeile,spalte):
        # load the hdf coocurence block
        if(zeile >= spalte):
            template = "co_occurence_{i}_{j}.hdf5".format(i=zeile,j=spalte)
        else:
            template = "co_occurence_{i}_{j}.hdf5".format(i=spalte,j=zeile)
        
        file_path =  self.block_path + '\\' + template
        
        tmp_hf = h5py.File(file_path, "r")
        coocurrence = tmp_hf.get("co-ocurrence")[:]
        if (spalte > zeile):
            coocurrence = np.transpose(coocurrence)
        self.tf_co_occurences = tf.convert_to_tensor(coocurrence,dtype=tf.dtypes.float32)
        coocurrence = None
        tmp_hf.close()
        self.load_weights(zeile,spalte)
        

    def load_weights(self,zeile,spalte):
        self.tf_con_bias = tf.Variable(initial_value=self.context_bias[zeile*self.block_length:(zeile+1)*self.block_length,:],dtype=tf.dtypes.float32)
        self.tf_bias = tf.Variable(initial_value=self.bias[:,spalte*self.block_length:(spalte+1)*self.block_length],dtype=tf.dtypes.float32)
        self.tf_con_weights =  tf.Variable(initial_value=self.con_weights[zeile*self.block_length:(zeile+1)*self.block_length,:],dtype=tf.dtypes.float32)
        self.tf_weights = tf.Variable(initial_value=self.weights[:,spalte*self.block_length:(spalte+1)*self.block_length],dtype=tf.dtypes.float32)
    
    def save_blocks(self,zeile,spalte):
        self.context_bias[zeile*self.block_length:(zeile+1)*self.block_length,:] = self.tf_con_bias.numpy()
        self.bias[0,spalte*self.block_length:(spalte+1)*self.block_length] = self.tf_bias.numpy()
        self.con_weights[zeile*self.block_length:(zeile+1)*self.block_length,:] = self.tf_con_weights.numpy()
        self.weights[:,spalte*self.block_length:(spalte+1)*self.block_length] = self.tf_weights.numpy()
    
    def _close_files(self):
        self.f.close()
        self.csv_writer.close()
        
    #@tf.function
    def loss(self,zeile,spalte):
        ones_symetrical = tf.ones((self.block_length,self.block_length), dtype=tf.dtypes.float32, name=None)
    
        #;ust the words context
        if(zeile == self.amount_split - 1):
            difference = self.block_length - self.tf_con_bias.shape[0]
            add2_context_bias   = tf.zeros((difference,1),dtype=tf.dtypes.float32)
            add2_context_weights = tf.zeros((difference,self.vector_size),dtype=tf.dtypes.float32)
            
            context_weights       = tf.concat([self.tf_con_weights,add2_context_weights],axis = 0)
            con_bias_mat   = tf.concat([self.tf_con_bias,add2_context_bias],axis = 0) * ones_symetrical
        else:
            con_bias_mat   = self.tf_con_bias * ones_symetrical
            context_weights       = self.tf_con_weights
        
        co_occurences = self.tf_co_occurences
        #;ust the words without context
        if(spalte == self.amount_split - 1):
            difference = self.block_length - self.tf_bias.shape[1]
            add2_bias = tf.zeros((1,difference),dtype=tf.dtypes.float32)
            add2_weights = tf.zeros((self.vector_size,difference),dtype=tf.dtypes.float32)
            
            weights = tf.concat([self.tf_weights,add2_weights],axis = 1)
            bias_mat = tf.concat([self.tf_bias,add2_bias],axis=1) * ones_symetrical
        else:
            weights     = self.tf_weights
            bias_mat = self.tf_bias * ones_symetrical
          
                                                          
        bias_terms = bias_mat + con_bias_mat
        weight_matrix = tf.matmul(context_weights,weights)
        log_X = tf.math.log(co_occurences + self.epsilon)
        inner_sum = bias_terms + weight_matrix - log_X
        squared_sum = tf.math.square(inner_sum)
        weighted_sum = self.cut_function2(co_occurences) * squared_sum
        reduced = tf.math.reduce_sum(weighted_sum)
        return reduced
    
    alpha = tf.constant(0.75,dtype=tf.dtypes.float32)
    XMAX = tf.constant(100.0,dtype=tf.dtypes.float32)
    
    def cut_function2(self,value):
        clipped = tf.clip_by_value(value, clip_value_min = 0.0, clip_value_max=100.0)
        return tf.pow(clipped / self.XMAX, self.alpha)
    
    def load_optimizer(self,epoch,zeile,spalte,optimizer_factory):
        #load optimizer & blocks
        if(epoch == 0):
            optimizer = optimizer_factory.create()
        else:
            name = 'S://optimizer{z}-{s}'.format(z = zeile,s = spalte)
            with open(name, "rb") as file:
                optimizer = cloudpickle.load(file)
            optimizer.learning_rate.assign(lrOnPlato.get_lr(epoch))
        return optimizer
        
        
        
    def train_splitted(self,epochs,keepWeights=False):
        #These can stay in memory
        
        self.epsilon = tf.constant(1e-8) * tf.ones((self.block_length,self.block_length),dtype=tf.dtypes.float32)
        
        
        
        for epoch in range(0,epochs):
            cur_loss = float(0.0)
            for zeile in range(0,self.amount_split):#self.amount_split
                for spalte in range(0,self.amount_split):#self.amount_split !!!!!!!!!!!!!!!!!!!?!?!!?!!?!?!!?
                    if spalte > zeile:
                        continue
                    
                    optimizer = tf.keras.optimizers.Adam(0.005)#first hundret with 0.005 second hundret with 0.0025
                    #train one side
                    self.load_blocks(zeile,spalte)
                    print(zeile,spalte)
                    
                    #train code
                    with tf.GradientTape() as tape:
                        tmp_loss = self.loss(zeile,spalte)
                    grads = tape.gradient(tmp_loss, [self.tf_con_bias,self.tf_bias,self.tf_con_weights,self.tf_weights])
                    optimizer.apply_gradients(zip(grads, [self.tf_con_bias,self.tf_bias,self.tf_con_weights,self.tf_weights]))
                    cur_loss += tmp_loss.numpy()
                    print(tmp_loss)
                    #print(optimizer.learning_rate)
                    self.save_blocks(zeile,spalte)
                
                    
                    #train the other side
                    
                    if spalte != zeile:
                        
                        optimizer = tf.keras.optimizers.Adam(0.005)
                        self.load_weights(spalte,zeile)
                        self.tf_co_occurences = tf.transpose(self.tf_co_occurences)
                    
                        #train code
                        with tf.GradientTape() as tape:
                            tmp_loss = self.loss(spalte,zeile)
                        grads = tape.gradient(tmp_loss, [self.tf_con_bias,self.tf_bias,self.tf_con_weights,self.tf_weights])
                        optimizer.apply_gradients(zip(grads, [self.tf_con_bias,self.tf_bias,self.tf_con_weights,self.tf_weights]))
                        cur_loss += tmp_loss.numpy()
                        print(tmp_loss)
                        #print(optimizer.learning_rate)
                        self.save_blocks(spalte,zeile)
                    
                        
                
            print('epoch'+str(epoch)+"loss:"+str(cur_loss))
            #lrOnPlato.notify_loss(cur_loss.numpy(),epoch)
            self.csv_writer.write('ADAM',0.0025,epoch+1,cur_loss)
        self._close_files()
        return None

# %%
vocab = Vocabulary()
vocab.load('..\\vocabs\\baseline')
size = vocab.get_size()

class AdamFactory:
    def __init__(self,lr = 0.001):
        self.lr = lr
    def create(self):
        return tf.keras.optimizers.Adam(self.lr)
    def optimiser_name(self):
        return "Adam"
    
    
#tf.keras.backend.clear_session()
#trainer = ModelTrainer(size,"S:\\base_coocurrence_hdf")
#trainer.prepare("baseline_postSanityCheck")
#trainer.train_splitted(10)

# %%
import time
startTime = time.time()
trainer2 = ModelTrainer(size,'S:\\base_coocurrence_hdf')
trainer2.resume("baseline_postSanityCheck")

trainer2.train_splitted(50)

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# amout_split: 8
# 0 0
# tf.Tensor(22130786.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(14736812.0, shape=(), dtype=float32)
# tf.Tensor(16730940.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(14668454.0, shape=(), dtype=float32)
# 2 0
# tf.Tensor(13673220.0, shape=(), dtype=float32)
# tf.Tensor(14330777.0, shape=(), dtype=float32)
# 2 1
# tf.Tensor(13478148.0, shape=(), dtype=float32)
# tf.Tensor(13043492.0, shape=(), dtype=float32)
# 2 2
# tf.Tensor(11868340.0, shape=(), dtype=float32)
# 3 0
# tf.Tensor(11971766.0, shape=(), dtype=float32)
# tf.Tensor(12456132.0, shape=(), dtype=float32)
# 3 1
# tf.Tensor(11667296.0, shape=(), dtype=float32)
# tf.Tensor(11303857.0, shape=(), dtype=float32)
# 3 2
# tf.Tensor(10188425.0, shape=(), dtype=float32)
# tf.Tensor(10175738.0, shape=(), dtype=float32)
# 3 3
# tf.Tensor(8635902.0, shape=(), dtype=float32)
# 4 0
# tf.Tensor(10568904.0, shape=(), dtype=float32)
# tf.Tensor(11006652.0, shape=(), dtype=float32)
# 4 1
# tf.Tensor(10348026.0, shape=(), dtype=float32)
# tf.Tensor(10108147.0, shape=(), dtype=float32)
# 4 2
# tf.Tensor(9040426.0, shape=(), dtype=float32)
# tf.Tensor(9088580.0, shape=(), dtype=float32)
# 4 3
# tf.Tensor(7601947.5, shape=(), dtype=float32)
# tf.Tensor(7648997.5, shape=(), dtype=float32)
# 4 4
# tf.Tensor(6702711.0, shape=(), dtype=float32)
# 5 0
# tf.Tensor(9719191.0, shape=(), dtype=float32)
# tf.Tensor(10117342.0, shape=(), dtype=float32)
# 5 1
# tf.Tensor(9285993.0, shape=(), dtype=float32)
# tf.Tensor(9103496.0, shape=(), dtype=float32)
# 5 2
# tf.Tensor(8038907.0, shape=(), dtype=float32)
# tf.Tensor(8077576.0, shape=(), dtype=float32)
# 5 3
# tf.Tensor(6677065.5, shape=(), dtype=float32)
# tf.Tensor(6695034.5, shape=(), dtype=float32)
# 5 4
# tf.Tensor(5834686.5, shape=(), dtype=float32)
# tf.Tensor(5810441.0, shape=(), dtype=float32)
# 5 5
# tf.Tensor(5008616.0, shape=(), dtype=float32)
# 6 0
# tf.Tensor(8917411.0, shape=(), dtype=float32)
# tf.Tensor(9248518.0, shape=(), dtype=float32)
# 6 1
# tf.Tensor(8505880.0, shape=(), dtype=float32)
# tf.Tensor(8356104.5, shape=(), dtype=float32)
# 6 2
# tf.Tensor(7333525.0, shape=(), dtype=float32)
# tf.Tensor(7371671.5, shape=(), dtype=float32)
# 6 3
# tf.Tensor(6040798.5, shape=(), dtype=float32)
# tf.Tensor(6055219.5, shape=(), dtype=float32)
# 6 4
# tf.Tensor(5241340.5, shape=(), dtype=float32)
# tf.Tensor(5215133.5, shape=(), dtype=float32)
# 6 5
# tf.Tensor(4460528.5, shape=(), dtype=float32)
# tf.Tensor(4458690.0, shape=(), dtype=float32)
# 6 6
# tf.Tensor(3944450.8, shape=(), dtype=float32)
# 7 0
# tf.Tensor(5552958.5, shape=(), dtype=float32)
# tf.Tensor(5672636.0, shape=(), dtype=float32)
# 7 1
# tf.Tensor(6323676.0, shape=(), dtype=float32)
# tf.Tensor(6236333.5, shape=(), dtype=float32)
# 7 2
# tf.Tensor(6461116.0, shape=(), dtype=float32)
# tf.Tensor(6560013.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(5845982.5, shape=(), dtype=float32)
# tf.Tensor(5867887.0, shape=(), dtype=float32)
# 7 4
# tf.Tensor(5812115.0, shape=(), dtype=float32)
# tf.Tensor(5804855.0, shape=(), dtype=float32)
# 7 5
# tf.Tensor(5499840.5, shape=(), dtype=float32)
# tf.Tensor(5513778.0, shape=(), dtype=float32)
# 7 6
# tf.Tensor(5510057.0, shape=(), dtype=float32)
# tf.Tensor(5505338.5, shape=(), dtype=float32)
# 7 7
# tf.Tensor(7797147.0, shape=(), dtype=float32)
# epoch0loss:552655829.25
# 0 0
# tf.Tensor(17105572.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(9146726.0, shape=(), dtype=float32)
# tf.Tensor(9574042.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(7730025.0, shape=(), dtype=float32)
# 2 0
# tf.Tensor(7390343.5, shape=(), dtype=float32)
# tf.Tensor(7609336.5, shape=(), dtype=float32)
# 2 1
# tf.Tensor(6656735.5, shape=(), dtype=float32)
# tf.Tensor(6514414.0, shape=(), dtype=float32)
# 2 2
# tf.Tensor(5606938.5, shape=(), dtype=float32)
# 3 0
# tf.Tensor(6173944.5, shape=(), dtype=float32)
# tf.Tensor(6358457.0, shape=(), dtype=float32)
# 3 1
# tf.Tensor(5598510.5, shape=(), dtype=float32)
# tf.Tensor(5482096.0, shape=(), dtype=float32)
# 3 2
# tf.Tensor(4684811.5, shape=(), dtype=float32)
# tf.Tensor(4688186.5, shape=(), dtype=float32)
# 3 3
# tf.Tensor(3910236.5, shape=(), dtype=float32)
# 4 0
# tf.Tensor(5337974.5, shape=(), dtype=float32)
# tf.Tensor(5526660.0, shape=(), dtype=float32)
# 4 1
# tf.Tensor(4831306.5, shape=(), dtype=float32)
# tf.Tensor(4750744.5, shape=(), dtype=float32)
# 4 2
# tf.Tensor(4021333.8, shape=(), dtype=float32)
# tf.Tensor(4043665.2, shape=(), dtype=float32)
# 4 3
# tf.Tensor(3333436.2, shape=(), dtype=float32)
# tf.Tensor(3351218.5, shape=(), dtype=float32)
# 4 4
# tf.Tensor(2852279.0, shape=(), dtype=float32)
# 5 0
# tf.Tensor(4705368.5, shape=(), dtype=float32)
# tf.Tensor(4862932.5, shape=(), dtype=float32)
# 5 1
# tf.Tensor(4221832.0, shape=(), dtype=float32)
# tf.Tensor(4140992.8, shape=(), dtype=float32)
# 5 2
# tf.Tensor(3494341.0, shape=(), dtype=float32)
# tf.Tensor(3505371.8, shape=(), dtype=float32)
# 5 3
# tf.Tensor(2883925.8, shape=(), dtype=float32)
# tf.Tensor(2890837.8, shape=(), dtype=float32)
# 5 4
# tf.Tensor(2454062.0, shape=(), dtype=float32)
# tf.Tensor(2447087.5, shape=(), dtype=float32)
# 5 5
# tf.Tensor(2105745.5, shape=(), dtype=float32)
# 6 0
# tf.Tensor(4222586.0, shape=(), dtype=float32)
# tf.Tensor(4373961.0, shape=(), dtype=float32)
# 6 1
# tf.Tensor(3777975.8, shape=(), dtype=float32)
# tf.Tensor(3708007.5, shape=(), dtype=float32)
# 6 2
# tf.Tensor(3112938.2, shape=(), dtype=float32)
# tf.Tensor(3125830.5, shape=(), dtype=float32)
# 6 3
# tf.Tensor(2558062.5, shape=(), dtype=float32)
# tf.Tensor(2568372.5, shape=(), dtype=float32)
# 6 4
# tf.Tensor(2168928.0, shape=(), dtype=float32)
# tf.Tensor(2165873.0, shape=(), dtype=float32)
# 6 5
# tf.Tensor(1851474.0, shape=(), dtype=float32)
# tf.Tensor(1854379.4, shape=(), dtype=float32)
# 6 6
# tf.Tensor(1634080.8, shape=(), dtype=float32)
# 7 0
# tf.Tensor(3512722.0, shape=(), dtype=float32)
# tf.Tensor(3531069.5, shape=(), dtype=float32)
# 7 1
# tf.Tensor(4202524.5, shape=(), dtype=float32)
# tf.Tensor(4161832.8, shape=(), dtype=float32)
# 7 2
# tf.Tensor(4620216.0, shape=(), dtype=float32)
# tf.Tensor(4699021.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(4431607.5, shape=(), dtype=float32)
# tf.Tensor(4450499.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(4604543.0, shape=(), dtype=float32)
# tf.Tensor(4612702.0, shape=(), dtype=float32)
# 7 5
# tf.Tensor(4508602.5, shape=(), dtype=float32)
# tf.Tensor(4520114.0, shape=(), dtype=float32)
# 7 6
# tf.Tensor(4609509.0, shape=(), dtype=float32)
# tf.Tensor(4591641.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(7324073.5, shape=(), dtype=float32)
# epoch1loss:295494637.625
# 0 0
# tf.Tensor(13699455.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(5568769.5, shape=(), dtype=float32)
# tf.Tensor(5789304.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(4090832.2, shape=(), dtype=float32)
# 2 0
# tf.Tensor(4129015.0, shape=(), dtype=float32)
# tf.Tensor(4240346.0, shape=(), dtype=float32)
# 2 1
# tf.Tensor(3377371.2, shape=(), dtype=float32)
# tf.Tensor(3302725.0, shape=(), dtype=float32)
# 2 2
# tf.Tensor(2742687.8, shape=(), dtype=float32)
# 3 0
# tf.Tensor(3313152.5, shape=(), dtype=float32)
# tf.Tensor(3410317.2, shape=(), dtype=float32)
# 3 1
# tf.Tensor(2765878.8, shape=(), dtype=float32)
# tf.Tensor(2705834.2, shape=(), dtype=float32)
# 3 2
# tf.Tensor(2227339.0, shape=(), dtype=float32)
# tf.Tensor(2229448.0, shape=(), dtype=float32)
# 3 3
# tf.Tensor(1815388.0, shape=(), dtype=float32)
# 4 0
# tf.Tensor(2778351.8, shape=(), dtype=float32)
# tf.Tensor(2876263.5, shape=(), dtype=float32)
# 4 1
# tf.Tensor(2332258.2, shape=(), dtype=float32)
# tf.Tensor(2291490.0, shape=(), dtype=float32)
# 4 2
# tf.Tensor(1867395.1, shape=(), dtype=float32)
# tf.Tensor(1878687.5, shape=(), dtype=float32)
# 4 3
# tf.Tensor(1507126.9, shape=(), dtype=float32)
# tf.Tensor(1515007.0, shape=(), dtype=float32)
# 4 4
# tf.Tensor(1263423.0, shape=(), dtype=float32)
# 5 0
# tf.Tensor(2399384.5, shape=(), dtype=float32)
# tf.Tensor(2480557.2, shape=(), dtype=float32)
# 5 1
# tf.Tensor(2002810.9, shape=(), dtype=float32)
# tf.Tensor(1961015.8, shape=(), dtype=float32)
# 5 2
# tf.Tensor(1594233.2, shape=(), dtype=float32)
# tf.Tensor(1599663.4, shape=(), dtype=float32)
# 5 3
# tf.Tensor(1284247.9, shape=(), dtype=float32)
# tf.Tensor(1284190.1, shape=(), dtype=float32)
# 5 4
# tf.Tensor(1081220.4, shape=(), dtype=float32)
# tf.Tensor(1063252.2, shape=(), dtype=float32)
# 5 5
# tf.Tensor(941174.75, shape=(), dtype=float32)
# 6 0
# tf.Tensor(2116017.5, shape=(), dtype=float32)
# tf.Tensor(2193902.5, shape=(), dtype=float32)
# 6 1
# tf.Tensor(1765621.8, shape=(), dtype=float32)
# tf.Tensor(1731559.4, shape=(), dtype=float32)
# 6 2
# tf.Tensor(1399979.9, shape=(), dtype=float32)
# tf.Tensor(1408049.5, shape=(), dtype=float32)
# 6 3
# tf.Tensor(1123932.6, shape=(), dtype=float32)
# tf.Tensor(1130859.5, shape=(), dtype=float32)
# 6 4
# tf.Tensor(968886.44, shape=(), dtype=float32)
# tf.Tensor(931112.8, shape=(), dtype=float32)
# 6 5
# tf.Tensor(884373.1, shape=(), dtype=float32)
# tf.Tensor(821753.0, shape=(), dtype=float32)
# 6 6
# tf.Tensor(795405.6, shape=(), dtype=float32)
# 7 0
# tf.Tensor(2611463.2, shape=(), dtype=float32)
# tf.Tensor(2592409.0, shape=(), dtype=float32)
# 7 1
# tf.Tensor(3323681.0, shape=(), dtype=float32)
# tf.Tensor(3297043.2, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3848523.8, shape=(), dtype=float32)
# tf.Tensor(3948382.2, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3830910.2, shape=(), dtype=float32)
# tf.Tensor(3801581.2, shape=(), dtype=float32)
# 7 4
# tf.Tensor(4028468.0, shape=(), dtype=float32)
# tf.Tensor(4074501.5, shape=(), dtype=float32)
# 7 5
# tf.Tensor(4121276.5, shape=(), dtype=float32)
# tf.Tensor(4090774.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(4213673.5, shape=(), dtype=float32)
# tf.Tensor(4189607.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(7154817.5, shape=(), dtype=float32)
# epoch2loss:177808184.0
# 0 0
# tf.Tensor(12813352.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(3681362.5, shape=(), dtype=float32)
# tf.Tensor(3799251.2, shape=(), dtype=float32)
# 1 1
# tf.Tensor(2165862.0, shape=(), dtype=float32)
# 2 0
# tf.Tensor(2423468.2, shape=(), dtype=float32)
# tf.Tensor(2477466.8, shape=(), dtype=float32)
# 2 1
# tf.Tensor(1700362.6, shape=(), dtype=float32)
# tf.Tensor(1652313.2, shape=(), dtype=float32)
# 2 2
# tf.Tensor(1324798.6, shape=(), dtype=float32)
# 3 0
# tf.Tensor(1869096.5, shape=(), dtype=float32)
# tf.Tensor(1900764.0, shape=(), dtype=float32)
# 3 1
# tf.Tensor(1372803.5, shape=(), dtype=float32)
# tf.Tensor(1317100.2, shape=(), dtype=float32)
# 3 2
# tf.Tensor(1068667.4, shape=(), dtype=float32)
# tf.Tensor(1061184.9, shape=(), dtype=float32)
# 3 3
# tf.Tensor(880729.5, shape=(), dtype=float32)
# 4 0
# tf.Tensor(1531595.8, shape=(), dtype=float32)
# tf.Tensor(1597518.6, shape=(), dtype=float32)
# 4 1
# tf.Tensor(1141872.0, shape=(), dtype=float32)
# tf.Tensor(1134083.4, shape=(), dtype=float32)
# 4 2
# tf.Tensor(897688.56, shape=(), dtype=float32)
# tf.Tensor(910158.7, shape=(), dtype=float32)
# 4 3
# tf.Tensor(773138.8, shape=(), dtype=float32)
# tf.Tensor(808887.75, shape=(), dtype=float32)
# 4 4
# tf.Tensor(655179.94, shape=(), dtype=float32)
# 5 0
# tf.Tensor(1322720.2, shape=(), dtype=float32)
# tf.Tensor(1398813.8, shape=(), dtype=float32)
# 5 1
# tf.Tensor(985726.9, shape=(), dtype=float32)
# tf.Tensor(989093.06, shape=(), dtype=float32)
# 5 2
# tf.Tensor(801069.56, shape=(), dtype=float32)
# tf.Tensor(784204.3, shape=(), dtype=float32)
# 5 3
# tf.Tensor(665663.4, shape=(), dtype=float32)
# tf.Tensor(675119.4, shape=(), dtype=float32)
# 5 4
# tf.Tensor(623078.4, shape=(), dtype=float32)
# tf.Tensor(618886.56, shape=(), dtype=float32)
# 5 5
# tf.Tensor(529029.1, shape=(), dtype=float32)
# 6 0
# tf.Tensor(1214192.9, shape=(), dtype=float32)
# tf.Tensor(1227005.2, shape=(), dtype=float32)
# 6 1
# tf.Tensor(923864.1, shape=(), dtype=float32)
# tf.Tensor(861390.44, shape=(), dtype=float32)
# 6 2
# tf.Tensor(759735.0, shape=(), dtype=float32)
# tf.Tensor(681974.0, shape=(), dtype=float32)
# 6 3
# tf.Tensor(675566.6, shape=(), dtype=float32)
# tf.Tensor(572031.06, shape=(), dtype=float32)
# 6 4
# tf.Tensor(568124.2, shape=(), dtype=float32)
# tf.Tensor(544290.3, shape=(), dtype=float32)
# 6 5
# tf.Tensor(552845.8, shape=(), dtype=float32)
# tf.Tensor(473801.4, shape=(), dtype=float32)
# 6 6
# tf.Tensor(481223.78, shape=(), dtype=float32)
# 7 0
# tf.Tensor(2233163.8, shape=(), dtype=float32)
# tf.Tensor(2182145.0, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2944158.2, shape=(), dtype=float32)
# tf.Tensor(2912527.0, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3515245.5, shape=(), dtype=float32)
# tf.Tensor(3660020.2, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3654085.8, shape=(), dtype=float32)
# tf.Tensor(3530952.2, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3746367.0, shape=(), dtype=float32)
# tf.Tensor(3844089.8, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3975086.5, shape=(), dtype=float32)
# tf.Tensor(3941287.5, shape=(), dtype=float32)
# 7 6
# tf.Tensor(4010343.0, shape=(), dtype=float32)
# tf.Tensor(3915173.5, shape=(), dtype=float32)
# 7 7
# tf.Tensor(7130147.5, shape=(), dtype=float32)
# epoch3loss:125082948.75
# 0 0
# tf.Tensor(12652387.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(2827215.0, shape=(), dtype=float32)
# tf.Tensor(2907058.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(1266520.4, shape=(), dtype=float32)
# 2 0
# tf.Tensor(1637443.2, shape=(), dtype=float32)
# tf.Tensor(1699470.4, shape=(), dtype=float32)
# 2 1
# tf.Tensor(936943.5, shape=(), dtype=float32)
# tf.Tensor(925149.9, shape=(), dtype=float32)
# 2 2
# tf.Tensor(734519.0, shape=(), dtype=float32)
# 3 0
# tf.Tensor(1237747.4, shape=(), dtype=float32)
# tf.Tensor(1278665.9, shape=(), dtype=float32)
# 3 1
# tf.Tensor(774877.9, shape=(), dtype=float32)
# tf.Tensor(753843.3, shape=(), dtype=float32)
# 3 2
# tf.Tensor(627220.6, shape=(), dtype=float32)
# tf.Tensor(637105.3, shape=(), dtype=float32)
# 3 3
# tf.Tensor(560397.6, shape=(), dtype=float32)
# 4 0
# tf.Tensor(997828.7, shape=(), dtype=float32)
# tf.Tensor(1053842.8, shape=(), dtype=float32)
# 4 1
# tf.Tensor(649444.7, shape=(), dtype=float32)
# tf.Tensor(668663.9, shape=(), dtype=float32)
# 4 2
# tf.Tensor(525521.75, shape=(), dtype=float32)
# tf.Tensor(518266.47, shape=(), dtype=float32)
# 4 3
# tf.Tensor(505509.38, shape=(), dtype=float32)
# tf.Tensor(481723.5, shape=(), dtype=float32)
# 4 4
# tf.Tensor(417318.7, shape=(), dtype=float32)
# 5 0
# tf.Tensor(864651.25, shape=(), dtype=float32)
# tf.Tensor(902627.56, shape=(), dtype=float32)
# 5 1
# tf.Tensor(651641.75, shape=(), dtype=float32)
# tf.Tensor(576388.94, shape=(), dtype=float32)
# 5 2
# tf.Tensor(468039.22, shape=(), dtype=float32)
# tf.Tensor(496896.78, shape=(), dtype=float32)
# 5 3
# tf.Tensor(487438.12, shape=(), dtype=float32)
# tf.Tensor(394878.8, shape=(), dtype=float32)
# 5 4
# tf.Tensor(376516.47, shape=(), dtype=float32)
# tf.Tensor(461884.4, shape=(), dtype=float32)
# 5 5
# tf.Tensor(358655.78, shape=(), dtype=float32)
# 6 0
# tf.Tensor(808894.94, shape=(), dtype=float32)
# tf.Tensor(782255.3, shape=(), dtype=float32)
# 6 1
# tf.Tensor(587030.8, shape=(), dtype=float32)
# tf.Tensor(481430.7, shape=(), dtype=float32)
# 6 2
# tf.Tensor(441023.7, shape=(), dtype=float32)
# tf.Tensor(461117.28, shape=(), dtype=float32)
# 6 3
# tf.Tensor(393793.0, shape=(), dtype=float32)
# tf.Tensor(338605.3, shape=(), dtype=float32)
# 6 4
# tf.Tensor(413977.78, shape=(), dtype=float32)
# tf.Tensor(297461.25, shape=(), dtype=float32)
# 6 5
# tf.Tensor(346873.75, shape=(), dtype=float32)
# tf.Tensor(329455.06, shape=(), dtype=float32)
# 6 6
# tf.Tensor(311738.62, shape=(), dtype=float32)
# 7 0
# tf.Tensor(2042707.8, shape=(), dtype=float32)
# tf.Tensor(1933614.9, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2741087.5, shape=(), dtype=float32)
# tf.Tensor(2718972.2, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3482381.5, shape=(), dtype=float32)
# tf.Tensor(3501723.8, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3535554.8, shape=(), dtype=float32)
# tf.Tensor(3305961.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3540456.0, shape=(), dtype=float32)
# tf.Tensor(3674362.0, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3907108.8, shape=(), dtype=float32)
# tf.Tensor(3845463.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3740018.2, shape=(), dtype=float32)
# tf.Tensor(3852028.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(7070987.5, shape=(), dtype=float32)
# epoch4loss:102200388.875
# 0 0
# tf.Tensor(12348675.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(2404356.5, shape=(), dtype=float32)
# tf.Tensor(2476445.2, shape=(), dtype=float32)
# 1 1
# tf.Tensor(847809.06, shape=(), dtype=float32)
# 2 0
# tf.Tensor(1274964.1, shape=(), dtype=float32)
# tf.Tensor(1299732.5, shape=(), dtype=float32)
# 2 1
# tf.Tensor(606757.44, shape=(), dtype=float32)
# tf.Tensor(580505.5, shape=(), dtype=float32)
# 2 2
# tf.Tensor(469484.38, shape=(), dtype=float32)
# 3 0
# tf.Tensor(915156.1, shape=(), dtype=float32)
# tf.Tensor(956960.8, shape=(), dtype=float32)
# 3 1
# tf.Tensor(504902.3, shape=(), dtype=float32)
# tf.Tensor(490478.5, shape=(), dtype=float32)
# 3 2
# tf.Tensor(406052.22, shape=(), dtype=float32)
# tf.Tensor(437916.84, shape=(), dtype=float32)
# 3 3
# tf.Tensor(380478.3, shape=(), dtype=float32)
# 4 0
# tf.Tensor(715662.8, shape=(), dtype=float32)
# tf.Tensor(749590.0, shape=(), dtype=float32)
# 4 1
# tf.Tensor(447043.03, shape=(), dtype=float32)
# tf.Tensor(406566.6, shape=(), dtype=float32)
# 4 2
# tf.Tensor(354483.03, shape=(), dtype=float32)
# tf.Tensor(357991.53, shape=(), dtype=float32)
# 4 3
# tf.Tensor(339571.16, shape=(), dtype=float32)
# tf.Tensor(319960.25, shape=(), dtype=float32)
# 4 4
# tf.Tensor(292523.25, shape=(), dtype=float32)
# 5 0
# tf.Tensor(636943.44, shape=(), dtype=float32)
# tf.Tensor(648064.7, shape=(), dtype=float32)
# 5 1
# tf.Tensor(390487.3, shape=(), dtype=float32)
# tf.Tensor(371931.53, shape=(), dtype=float32)
# 5 2
# tf.Tensor(394574.38, shape=(), dtype=float32)
# tf.Tensor(387737.6, shape=(), dtype=float32)
# 5 3
# tf.Tensor(301518.97, shape=(), dtype=float32)
# tf.Tensor(293314.44, shape=(), dtype=float32)
# 5 4
# tf.Tensor(306185.97, shape=(), dtype=float32)
# tf.Tensor(320801.84, shape=(), dtype=float32)
# 5 5
# tf.Tensor(240924.28, shape=(), dtype=float32)
# 6 0
# tf.Tensor(578323.1, shape=(), dtype=float32)
# tf.Tensor(544750.2, shape=(), dtype=float32)
# 6 1
# tf.Tensor(382806.5, shape=(), dtype=float32)
# tf.Tensor(329821.78, shape=(), dtype=float32)
# 6 2
# tf.Tensor(336110.47, shape=(), dtype=float32)
# tf.Tensor(253736.95, shape=(), dtype=float32)
# 6 3
# tf.Tensor(303135.3, shape=(), dtype=float32)
# tf.Tensor(291279.6, shape=(), dtype=float32)
# 6 4
# tf.Tensor(280380.16, shape=(), dtype=float32)
# tf.Tensor(199864.66, shape=(), dtype=float32)
# 6 5
# tf.Tensor(271965.56, shape=(), dtype=float32)
# tf.Tensor(280668.97, shape=(), dtype=float32)
# 6 6
# tf.Tensor(199452.81, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1881292.2, shape=(), dtype=float32)
# tf.Tensor(1820665.1, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2623127.0, shape=(), dtype=float32)
# tf.Tensor(2633035.5, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3304602.0, shape=(), dtype=float32)
# tf.Tensor(3397598.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3488262.0, shape=(), dtype=float32)
# tf.Tensor(3202487.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3419004.0, shape=(), dtype=float32)
# tf.Tensor(3631100.2, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3886443.0, shape=(), dtype=float32)
# tf.Tensor(3708373.0, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3589834.0, shape=(), dtype=float32)
# tf.Tensor(3655025.2, shape=(), dtype=float32)
# 7 7
# tf.Tensor(7056778.5, shape=(), dtype=float32)
# epoch5loss:90226474.421875
# 0 0
# tf.Tensor(11922122.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(2182903.2, shape=(), dtype=float32)
# tf.Tensor(2216766.5, shape=(), dtype=float32)
# 1 1
# tf.Tensor(645045.25, shape=(), dtype=float32)
# 2 0
# tf.Tensor(1098187.9, shape=(), dtype=float32)
# tf.Tensor(1121949.1, shape=(), dtype=float32)
# 2 1
# tf.Tensor(430928.06, shape=(), dtype=float32)
# tf.Tensor(430512.3, shape=(), dtype=float32)
# 2 2
# tf.Tensor(356968.5, shape=(), dtype=float32)
# 3 0
# tf.Tensor(796891.2, shape=(), dtype=float32)
# tf.Tensor(787830.5, shape=(), dtype=float32)
# 3 1
# tf.Tensor(426127.72, shape=(), dtype=float32)
# tf.Tensor(348086.25, shape=(), dtype=float32)
# 3 2
# tf.Tensor(277801.7, shape=(), dtype=float32)
# tf.Tensor(346666.06, shape=(), dtype=float32)
# 3 3
# tf.Tensor(322779.62, shape=(), dtype=float32)
# 4 0
# tf.Tensor(596491.3, shape=(), dtype=float32)
# tf.Tensor(601301.1, shape=(), dtype=float32)
# 4 1
# tf.Tensor(335425.56, shape=(), dtype=float32)
# tf.Tensor(288698.06, shape=(), dtype=float32)
# 4 2
# tf.Tensor(307107.1, shape=(), dtype=float32)
# tf.Tensor(257520.16, shape=(), dtype=float32)
# 4 3
# tf.Tensor(249745.39, shape=(), dtype=float32)
# tf.Tensor(245300.56, shape=(), dtype=float32)
# 4 4
# tf.Tensor(264621.06, shape=(), dtype=float32)
# 5 0
# tf.Tensor(525411.2, shape=(), dtype=float32)
# tf.Tensor(514218.66, shape=(), dtype=float32)
# 5 1
# tf.Tensor(294245.1, shape=(), dtype=float32)
# tf.Tensor(256461.47, shape=(), dtype=float32)
# 5 2
# tf.Tensor(255818.03, shape=(), dtype=float32)
# tf.Tensor(262815.62, shape=(), dtype=float32)
# 5 3
# tf.Tensor(264293.28, shape=(), dtype=float32)
# tf.Tensor(268413.4, shape=(), dtype=float32)
# 5 4
# tf.Tensor(228865.36, shape=(), dtype=float32)
# tf.Tensor(205060.0, shape=(), dtype=float32)
# 5 5
# tf.Tensor(267844.66, shape=(), dtype=float32)
# 6 0
# tf.Tensor(467050.34, shape=(), dtype=float32)
# tf.Tensor(411160.97, shape=(), dtype=float32)
# 6 1
# tf.Tensor(275437.88, shape=(), dtype=float32)
# tf.Tensor(218157.39, shape=(), dtype=float32)
# 6 2
# tf.Tensor(260293.55, shape=(), dtype=float32)
# tf.Tensor(181089.66, shape=(), dtype=float32)
# 6 3
# tf.Tensor(241133.9, shape=(), dtype=float32)
# tf.Tensor(190879.81, shape=(), dtype=float32)
# 6 4
# tf.Tensor(223154.38, shape=(), dtype=float32)
# tf.Tensor(197290.5, shape=(), dtype=float32)
# 6 5
# tf.Tensor(218298.03, shape=(), dtype=float32)
# tf.Tensor(199166.95, shape=(), dtype=float32)
# 6 6
# tf.Tensor(198544.33, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1825056.5, shape=(), dtype=float32)
# tf.Tensor(1716176.0, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2518927.2, shape=(), dtype=float32)
# tf.Tensor(2542743.8, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3205918.0, shape=(), dtype=float32)
# tf.Tensor(3324989.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3355687.2, shape=(), dtype=float32)
# tf.Tensor(3086812.8, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3334328.2, shape=(), dtype=float32)
# tf.Tensor(3550948.5, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3814668.0, shape=(), dtype=float32)
# tf.Tensor(3679593.2, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3543670.5, shape=(), dtype=float32)
# tf.Tensor(3627413.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6975406.5, shape=(), dtype=float32)
# epoch6loss:83585219.9375
# 0 0
# tf.Tensor(11544760.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(2088490.9, shape=(), dtype=float32)
# tf.Tensor(2070243.8, shape=(), dtype=float32)
# 1 1
# tf.Tensor(547970.75, shape=(), dtype=float32)
# 2 0
# tf.Tensor(1005086.44, shape=(), dtype=float32)
# tf.Tensor(995684.9, shape=(), dtype=float32)
# 2 1
# tf.Tensor(357496.4, shape=(), dtype=float32)
# tf.Tensor(356273.94, shape=(), dtype=float32)
# 2 2
# tf.Tensor(274201.8, shape=(), dtype=float32)
# 3 0
# tf.Tensor(722546.8, shape=(), dtype=float32)
# tf.Tensor(694126.94, shape=(), dtype=float32)
# 3 1
# tf.Tensor(339713.53, shape=(), dtype=float32)
# tf.Tensor(297113.7, shape=(), dtype=float32)
# 3 2
# tf.Tensor(231233.58, shape=(), dtype=float32)
# tf.Tensor(256485.75, shape=(), dtype=float32)
# 3 3
# tf.Tensor(259132.36, shape=(), dtype=float32)
# 4 0
# tf.Tensor(521654.16, shape=(), dtype=float32)
# tf.Tensor(515906.66, shape=(), dtype=float32)
# 4 1
# tf.Tensor(286566.97, shape=(), dtype=float32)
# tf.Tensor(265421.34, shape=(), dtype=float32)
# 4 2
# tf.Tensor(192569.52, shape=(), dtype=float32)
# tf.Tensor(202505.84, shape=(), dtype=float32)
# 4 3
# tf.Tensor(216941.39, shape=(), dtype=float32)
# tf.Tensor(193495.7, shape=(), dtype=float32)
# 4 4
# tf.Tensor(169840.8, shape=(), dtype=float32)
# 5 0
# tf.Tensor(482253.16, shape=(), dtype=float32)
# tf.Tensor(444384.2, shape=(), dtype=float32)
# 5 1
# tf.Tensor(296206.34, shape=(), dtype=float32)
# tf.Tensor(215719.66, shape=(), dtype=float32)
# 5 2
# tf.Tensor(194117.58, shape=(), dtype=float32)
# tf.Tensor(251039.03, shape=(), dtype=float32)
# 5 3
# tf.Tensor(226611.31, shape=(), dtype=float32)
# tf.Tensor(193573.39, shape=(), dtype=float32)
# 5 4
# tf.Tensor(167456.81, shape=(), dtype=float32)
# tf.Tensor(216935.97, shape=(), dtype=float32)
# 5 5
# tf.Tensor(183439.86, shape=(), dtype=float32)
# 6 0
# tf.Tensor(403074.97, shape=(), dtype=float32)
# tf.Tensor(367563.84, shape=(), dtype=float32)
# 6 1
# tf.Tensor(279392.56, shape=(), dtype=float32)
# tf.Tensor(230441.28, shape=(), dtype=float32)
# 6 2
# tf.Tensor(177241.64, shape=(), dtype=float32)
# tf.Tensor(166502.17, shape=(), dtype=float32)
# 6 3
# tf.Tensor(222938.77, shape=(), dtype=float32)
# tf.Tensor(174242.7, shape=(), dtype=float32)
# 6 4
# tf.Tensor(152659.17, shape=(), dtype=float32)
# tf.Tensor(140181.78, shape=(), dtype=float32)
# 6 5
# tf.Tensor(215192.81, shape=(), dtype=float32)
# tf.Tensor(157810.56, shape=(), dtype=float32)
# 6 6
# tf.Tensor(132722.08, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1808635.2, shape=(), dtype=float32)
# tf.Tensor(1673546.8, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2505245.5, shape=(), dtype=float32)
# tf.Tensor(2531540.0, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3141210.2, shape=(), dtype=float32)
# tf.Tensor(3234296.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3330501.2, shape=(), dtype=float32)
# tf.Tensor(3076413.0, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3257720.0, shape=(), dtype=float32)
# tf.Tensor(3470387.8, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3713321.5, shape=(), dtype=float32)
# tf.Tensor(3664787.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3427739.0, shape=(), dtype=float32)
# tf.Tensor(3508091.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6937705.0, shape=(), dtype=float32)
# epoch7loss:79578305.515625
# 0 0
# tf.Tensor(10768317.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1971455.8, shape=(), dtype=float32)
# tf.Tensor(1977139.2, shape=(), dtype=float32)
# 1 1
# tf.Tensor(496472.9, shape=(), dtype=float32)
# 2 0
# tf.Tensor(969444.44, shape=(), dtype=float32)
# tf.Tensor(936249.5, shape=(), dtype=float32)
# 2 1
# tf.Tensor(317888.0, shape=(), dtype=float32)
# tf.Tensor(282896.5, shape=(), dtype=float32)
# 2 2
# tf.Tensor(250025.28, shape=(), dtype=float32)
# 3 0
# tf.Tensor(688085.3, shape=(), dtype=float32)
# tf.Tensor(650670.1, shape=(), dtype=float32)
# 3 1
# tf.Tensor(316263.28, shape=(), dtype=float32)
# tf.Tensor(251655.75, shape=(), dtype=float32)
# 3 2
# tf.Tensor(206233.44, shape=(), dtype=float32)
# tf.Tensor(224608.17, shape=(), dtype=float32)
# 3 3
# tf.Tensor(257721.78, shape=(), dtype=float32)
# 4 0
# tf.Tensor(495996.34, shape=(), dtype=float32)
# tf.Tensor(472359.3, shape=(), dtype=float32)
# 4 1
# tf.Tensor(266063.72, shape=(), dtype=float32)
# tf.Tensor(198083.94, shape=(), dtype=float32)
# 4 2
# tf.Tensor(187240.69, shape=(), dtype=float32)
# tf.Tensor(193177.66, shape=(), dtype=float32)
# 4 3
# tf.Tensor(209525.55, shape=(), dtype=float32)
# tf.Tensor(165638.42, shape=(), dtype=float32)
# 4 4
# tf.Tensor(170007.17, shape=(), dtype=float32)
# 5 0
# tf.Tensor(442996.12, shape=(), dtype=float32)
# tf.Tensor(407157.44, shape=(), dtype=float32)
# 5 1
# tf.Tensor(267963.9, shape=(), dtype=float32)
# tf.Tensor(166427.77, shape=(), dtype=float32)
# 5 2
# tf.Tensor(184020.77, shape=(), dtype=float32)
# tf.Tensor(172226.05, shape=(), dtype=float32)
# 5 3
# tf.Tensor(220547.61, shape=(), dtype=float32)
# tf.Tensor(194094.88, shape=(), dtype=float32)
# 5 4
# tf.Tensor(164400.81, shape=(), dtype=float32)
# tf.Tensor(179087.61, shape=(), dtype=float32)
# 5 5
# tf.Tensor(195539.25, shape=(), dtype=float32)
# 6 0
# tf.Tensor(364217.66, shape=(), dtype=float32)
# tf.Tensor(317673.66, shape=(), dtype=float32)
# 6 1
# tf.Tensor(240061.75, shape=(), dtype=float32)
# tf.Tensor(145869.62, shape=(), dtype=float32)
# 6 2
# tf.Tensor(166542.6, shape=(), dtype=float32)
# tf.Tensor(127728.48, shape=(), dtype=float32)
# 6 3
# tf.Tensor(200573.06, shape=(), dtype=float32)
# tf.Tensor(145141.86, shape=(), dtype=float32)
# 6 4
# tf.Tensor(151144.55, shape=(), dtype=float32)
# tf.Tensor(122195.0, shape=(), dtype=float32)
# 6 5
# tf.Tensor(180546.25, shape=(), dtype=float32)
# tf.Tensor(152530.9, shape=(), dtype=float32)
# 6 6
# tf.Tensor(129465.02, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1713478.1, shape=(), dtype=float32)
# tf.Tensor(1610106.4, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2436238.5, shape=(), dtype=float32)
# tf.Tensor(2464490.8, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3087196.5, shape=(), dtype=float32)
# tf.Tensor(3178563.5, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3242384.5, shape=(), dtype=float32)
# tf.Tensor(2959169.8, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3198440.0, shape=(), dtype=float32)
# tf.Tensor(3436595.5, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3668706.2, shape=(), dtype=float32)
# tf.Tensor(3539182.0, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3385047.2, shape=(), dtype=float32)
# tf.Tensor(3486024.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6862689.0, shape=(), dtype=float32)
# epoch8loss:76229683.890625
# 0 0
# tf.Tensor(10474489.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1919731.6, shape=(), dtype=float32)
# tf.Tensor(1899577.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(476968.03, shape=(), dtype=float32)
# 2 0
# tf.Tensor(892137.44, shape=(), dtype=float32)
# tf.Tensor(882813.8, shape=(), dtype=float32)
# 2 1
# tf.Tensor(318377.84, shape=(), dtype=float32)
# tf.Tensor(271045.38, shape=(), dtype=float32)
# 2 2
# tf.Tensor(220185.81, shape=(), dtype=float32)
# 3 0
# tf.Tensor(625940.75, shape=(), dtype=float32)
# tf.Tensor(601950.1, shape=(), dtype=float32)
# 3 1
# tf.Tensor(259802.98, shape=(), dtype=float32)
# tf.Tensor(218644.78, shape=(), dtype=float32)
# 3 2
# tf.Tensor(185712.78, shape=(), dtype=float32)
# tf.Tensor(238436.19, shape=(), dtype=float32)
# 3 3
# tf.Tensor(193913.83, shape=(), dtype=float32)
# 4 0
# tf.Tensor(453300.12, shape=(), dtype=float32)
# tf.Tensor(437070.0, shape=(), dtype=float32)
# 4 1
# tf.Tensor(261336.0, shape=(), dtype=float32)
# tf.Tensor(181241.4, shape=(), dtype=float32)
# 4 2
# tf.Tensor(158061.72, shape=(), dtype=float32)
# tf.Tensor(156453.55, shape=(), dtype=float32)
# 4 3
# tf.Tensor(211425.1, shape=(), dtype=float32)
# tf.Tensor(151698.84, shape=(), dtype=float32)
# 4 4
# tf.Tensor(147278.61, shape=(), dtype=float32)
# 5 0
# tf.Tensor(402479.3, shape=(), dtype=float32)
# tf.Tensor(368593.75, shape=(), dtype=float32)
# 5 1
# tf.Tensor(235802.38, shape=(), dtype=float32)
# tf.Tensor(144669.58, shape=(), dtype=float32)
# 5 2
# tf.Tensor(159141.92, shape=(), dtype=float32)
# tf.Tensor(209396.22, shape=(), dtype=float32)
# 5 3
# tf.Tensor(175817.47, shape=(), dtype=float32)
# tf.Tensor(141516.78, shape=(), dtype=float32)
# 5 4
# tf.Tensor(133473.12, shape=(), dtype=float32)
# tf.Tensor(192454.0, shape=(), dtype=float32)
# 5 5
# tf.Tensor(148238.94, shape=(), dtype=float32)
# 6 0
# tf.Tensor(348389.84, shape=(), dtype=float32)
# tf.Tensor(299956.22, shape=(), dtype=float32)
# 6 1
# tf.Tensor(249692.97, shape=(), dtype=float32)
# tf.Tensor(117731.07, shape=(), dtype=float32)
# 6 2
# tf.Tensor(142829.66, shape=(), dtype=float32)
# tf.Tensor(125184.37, shape=(), dtype=float32)
# 6 3
# tf.Tensor(210678.6, shape=(), dtype=float32)
# tf.Tensor(116511.61, shape=(), dtype=float32)
# 6 4
# tf.Tensor(131187.08, shape=(), dtype=float32)
# tf.Tensor(120575.24, shape=(), dtype=float32)
# 6 5
# tf.Tensor(193937.08, shape=(), dtype=float32)
# tf.Tensor(103399.24, shape=(), dtype=float32)
# 6 6
# tf.Tensor(119494.09, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1690781.0, shape=(), dtype=float32)
# tf.Tensor(1568559.8, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2411442.0, shape=(), dtype=float32)
# tf.Tensor(2458007.5, shape=(), dtype=float32)
# 7 2
# tf.Tensor(3016371.2, shape=(), dtype=float32)
# tf.Tensor(3127507.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3182149.2, shape=(), dtype=float32)
# tf.Tensor(2927226.2, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3117297.2, shape=(), dtype=float32)
# tf.Tensor(3347812.5, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3579678.0, shape=(), dtype=float32)
# tf.Tensor(3513928.2, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3282957.0, shape=(), dtype=float32)
# tf.Tensor(3383453.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6813071.5, shape=(), dtype=float32)
# epoch9loss:73848984.75
# 0 0
# tf.Tensor(10214540.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1841546.6, shape=(), dtype=float32)
# tf.Tensor(1845733.4, shape=(), dtype=float32)
# 1 1
# tf.Tensor(420560.94, shape=(), dtype=float32)
# 2 0
# tf.Tensor(876411.25, shape=(), dtype=float32)
# tf.Tensor(858883.56, shape=(), dtype=float32)
# 2 1
# tf.Tensor(291435.62, shape=(), dtype=float32)
# tf.Tensor(226068.11, shape=(), dtype=float32)
# 2 2
# tf.Tensor(199099.95, shape=(), dtype=float32)
# 3 0
# tf.Tensor(609039.8, shape=(), dtype=float32)
# tf.Tensor(586594.44, shape=(), dtype=float32)
# 3 1
# tf.Tensor(269141.62, shape=(), dtype=float32)
# tf.Tensor(180702.52, shape=(), dtype=float32)
# 3 2
# tf.Tensor(160468.16, shape=(), dtype=float32)
# tf.Tensor(185743.89, shape=(), dtype=float32)
# 3 3
# tf.Tensor(203434.1, shape=(), dtype=float32)
# 4 0
# tf.Tensor(464385.0, shape=(), dtype=float32)
# tf.Tensor(418601.5, shape=(), dtype=float32)
# 4 1
# tf.Tensor(241988.17, shape=(), dtype=float32)
# tf.Tensor(143815.81, shape=(), dtype=float32)
# 4 2
# tf.Tensor(153717.61, shape=(), dtype=float32)
# tf.Tensor(134472.06, shape=(), dtype=float32)
# 4 3
# tf.Tensor(183887.33, shape=(), dtype=float32)
# tf.Tensor(133630.62, shape=(), dtype=float32)
# 4 4
# tf.Tensor(138301.73, shape=(), dtype=float32)
# 5 0
# tf.Tensor(412673.12, shape=(), dtype=float32)
# tf.Tensor(362376.9, shape=(), dtype=float32)
# 5 1
# tf.Tensor(223163.7, shape=(), dtype=float32)
# tf.Tensor(127581.766, shape=(), dtype=float32)
# 5 2
# tf.Tensor(143733.16, shape=(), dtype=float32)
# tf.Tensor(152478.45, shape=(), dtype=float32)
# 5 3
# tf.Tensor(168923.72, shape=(), dtype=float32)
# tf.Tensor(148482.56, shape=(), dtype=float32)
# 5 4
# tf.Tensor(130290.305, shape=(), dtype=float32)
# tf.Tensor(163341.69, shape=(), dtype=float32)
# 5 5
# tf.Tensor(150860.64, shape=(), dtype=float32)
# 6 0
# tf.Tensor(347439.25, shape=(), dtype=float32)
# tf.Tensor(271052.0, shape=(), dtype=float32)
# 6 1
# tf.Tensor(218313.08, shape=(), dtype=float32)
# tf.Tensor(100600.82, shape=(), dtype=float32)
# 6 2
# tf.Tensor(137667.97, shape=(), dtype=float32)
# tf.Tensor(109724.125, shape=(), dtype=float32)
# 6 3
# tf.Tensor(175974.16, shape=(), dtype=float32)
# tf.Tensor(107962.77, shape=(), dtype=float32)
# 6 4
# tf.Tensor(118834.875, shape=(), dtype=float32)
# tf.Tensor(103710.125, shape=(), dtype=float32)
# 6 5
# tf.Tensor(168537.52, shape=(), dtype=float32)
# tf.Tensor(113643.14, shape=(), dtype=float32)
# 6 6
# tf.Tensor(107329.24, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1642574.2, shape=(), dtype=float32)
# tf.Tensor(1517688.2, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2378772.5, shape=(), dtype=float32)
# tf.Tensor(2376631.5, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2980574.8, shape=(), dtype=float32)
# tf.Tensor(3080188.2, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3142285.2, shape=(), dtype=float32)
# tf.Tensor(2822563.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3081190.8, shape=(), dtype=float32)
# tf.Tensor(3319699.0, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3554665.5, shape=(), dtype=float32)
# tf.Tensor(3393970.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3239946.8, shape=(), dtype=float32)
# tf.Tensor(3363969.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6751921.5, shape=(), dtype=float32)
# epoch10loss:71893541.15625
# 0 0
# tf.Tensor(9832689.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1842830.9, shape=(), dtype=float32)
# tf.Tensor(1785113.5, shape=(), dtype=float32)
# 1 1
# tf.Tensor(401953.2, shape=(), dtype=float32)
# 2 0
# tf.Tensor(836763.25, shape=(), dtype=float32)
# tf.Tensor(826558.5, shape=(), dtype=float32)
# 2 1
# tf.Tensor(337714.62, shape=(), dtype=float32)
# tf.Tensor(198731.14, shape=(), dtype=float32)
# 2 2
# tf.Tensor(177906.34, shape=(), dtype=float32)
# 3 0
# tf.Tensor(608771.94, shape=(), dtype=float32)
# tf.Tensor(560492.0, shape=(), dtype=float32)
# 3 1
# tf.Tensor(214105.52, shape=(), dtype=float32)
# tf.Tensor(163139.75, shape=(), dtype=float32)
# 3 2
# tf.Tensor(143196.88, shape=(), dtype=float32)
# tf.Tensor(190140.95, shape=(), dtype=float32)
# 3 3
# tf.Tensor(165714.48, shape=(), dtype=float32)
# 4 0
# tf.Tensor(413234.9, shape=(), dtype=float32)
# tf.Tensor(390369.0, shape=(), dtype=float32)
# 4 1
# tf.Tensor(262622.56, shape=(), dtype=float32)
# tf.Tensor(118109.45, shape=(), dtype=float32)
# 4 2
# tf.Tensor(133974.88, shape=(), dtype=float32)
# tf.Tensor(107166.125, shape=(), dtype=float32)
# 4 3
# tf.Tensor(176250.92, shape=(), dtype=float32)
# tf.Tensor(125359.93, shape=(), dtype=float32)
# 4 4
# tf.Tensor(118297.8, shape=(), dtype=float32)
# 5 0
# tf.Tensor(378320.6, shape=(), dtype=float32)
# tf.Tensor(341452.44, shape=(), dtype=float32)
# 5 1
# tf.Tensor(185589.84, shape=(), dtype=float32)
# tf.Tensor(114987.76, shape=(), dtype=float32)
# 5 2
# tf.Tensor(133695.23, shape=(), dtype=float32)
# tf.Tensor(113027.64, shape=(), dtype=float32)
# 5 3
# tf.Tensor(152231.12, shape=(), dtype=float32)
# tf.Tensor(159729.02, shape=(), dtype=float32)
# 5 4
# tf.Tensor(116381.2, shape=(), dtype=float32)
# tf.Tensor(128924.484, shape=(), dtype=float32)
# 5 5
# tf.Tensor(173847.81, shape=(), dtype=float32)
# 6 0
# tf.Tensor(305504.5, shape=(), dtype=float32)
# tf.Tensor(258642.36, shape=(), dtype=float32)
# 6 1
# tf.Tensor(246189.03, shape=(), dtype=float32)
# tf.Tensor(89219.836, shape=(), dtype=float32)
# 6 2
# tf.Tensor(119421.8, shape=(), dtype=float32)
# tf.Tensor(77606.21, shape=(), dtype=float32)
# 6 3
# tf.Tensor(176176.33, shape=(), dtype=float32)
# tf.Tensor(108327.64, shape=(), dtype=float32)
# 6 4
# tf.Tensor(106987.61, shape=(), dtype=float32)
# tf.Tensor(99122.914, shape=(), dtype=float32)
# 6 5
# tf.Tensor(130359.66, shape=(), dtype=float32)
# tf.Tensor(101550.88, shape=(), dtype=float32)
# 6 6
# tf.Tensor(97620.21, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1615568.8, shape=(), dtype=float32)
# tf.Tensor(1494969.8, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2294160.2, shape=(), dtype=float32)
# tf.Tensor(2348583.0, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2922893.8, shape=(), dtype=float32)
# tf.Tensor(2957655.8, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3072074.2, shape=(), dtype=float32)
# tf.Tensor(2846035.0, shape=(), dtype=float32)
# 7 4
# tf.Tensor(3004708.5, shape=(), dtype=float32)
# tf.Tensor(3190487.2, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3523694.2, shape=(), dtype=float32)
# tf.Tensor(3425278.2, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3144919.5, shape=(), dtype=float32)
# tf.Tensor(3219672.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6753671.5, shape=(), dtype=float32)
# epoch11loss:69860496.1328125
# 0 0
# tf.Tensor(9535264.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1790692.5, shape=(), dtype=float32)
# tf.Tensor(1790527.9, shape=(), dtype=float32)
# 1 1
# tf.Tensor(384082.97, shape=(), dtype=float32)
# 2 0
# tf.Tensor(816456.8, shape=(), dtype=float32)
# tf.Tensor(805286.2, shape=(), dtype=float32)
# 2 1
# tf.Tensor(255930.12, shape=(), dtype=float32)
# tf.Tensor(189028.34, shape=(), dtype=float32)
# 2 2
# tf.Tensor(171973.94, shape=(), dtype=float32)
# 3 0
# tf.Tensor(559732.25, shape=(), dtype=float32)
# tf.Tensor(547716.06, shape=(), dtype=float32)
# 3 1
# tf.Tensor(251076.81, shape=(), dtype=float32)
# tf.Tensor(144676.56, shape=(), dtype=float32)
# 3 2
# tf.Tensor(136529.36, shape=(), dtype=float32)
# tf.Tensor(149931.66, shape=(), dtype=float32)
# 3 3
# tf.Tensor(195492.97, shape=(), dtype=float32)
# 4 0
# tf.Tensor(417571.7, shape=(), dtype=float32)
# tf.Tensor(382811.9, shape=(), dtype=float32)
# 4 1
# tf.Tensor(194315.22, shape=(), dtype=float32)
# tf.Tensor(109555.78, shape=(), dtype=float32)
# 4 2
# tf.Tensor(128216.805, shape=(), dtype=float32)
# tf.Tensor(98745.65, shape=(), dtype=float32)
# 4 3
# tf.Tensor(148540.69, shape=(), dtype=float32)
# tf.Tensor(115587.29, shape=(), dtype=float32)
# 4 4
# tf.Tensor(112493.67, shape=(), dtype=float32)
# 5 0
# tf.Tensor(370895.66, shape=(), dtype=float32)
# tf.Tensor(321802.62, shape=(), dtype=float32)
# 5 1
# tf.Tensor(219587.1, shape=(), dtype=float32)
# tf.Tensor(95471.89, shape=(), dtype=float32)
# 5 2
# tf.Tensor(118920.11, shape=(), dtype=float32)
# tf.Tensor(111378.336, shape=(), dtype=float32)
# 5 3
# tf.Tensor(168589.22, shape=(), dtype=float32)
# tf.Tensor(143935.62, shape=(), dtype=float32)
# 5 4
# tf.Tensor(116275.41, shape=(), dtype=float32)
# tf.Tensor(136516.2, shape=(), dtype=float32)
# 5 5
# tf.Tensor(151806.97, shape=(), dtype=float32)
# 6 0
# tf.Tensor(301298.56, shape=(), dtype=float32)
# tf.Tensor(248326.05, shape=(), dtype=float32)
# 6 1
# tf.Tensor(172211.36, shape=(), dtype=float32)
# tf.Tensor(77483.03, shape=(), dtype=float32)
# 6 2
# tf.Tensor(112857.19, shape=(), dtype=float32)
# tf.Tensor(86959.54, shape=(), dtype=float32)
# 6 3
# tf.Tensor(140489.83, shape=(), dtype=float32)
# tf.Tensor(76696.33, shape=(), dtype=float32)
# 6 4
# tf.Tensor(92158.91, shape=(), dtype=float32)
# tf.Tensor(91281.67, shape=(), dtype=float32)
# 6 5
# tf.Tensor(137735.22, shape=(), dtype=float32)
# tf.Tensor(93171.88, shape=(), dtype=float32)
# 6 6
# tf.Tensor(91193.46, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1563931.0, shape=(), dtype=float32)
# tf.Tensor(1430855.9, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2282083.0, shape=(), dtype=float32)
# tf.Tensor(2269266.0, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2887077.5, shape=(), dtype=float32)
# tf.Tensor(2958624.5, shape=(), dtype=float32)
# 7 3
# tf.Tensor(3002914.0, shape=(), dtype=float32)
# tf.Tensor(2716511.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2976611.2, shape=(), dtype=float32)
# tf.Tensor(3182762.8, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3402760.2, shape=(), dtype=float32)
# tf.Tensor(3271687.0, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3092261.0, shape=(), dtype=float32)
# tf.Tensor(3224476.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6627552.0, shape=(), dtype=float32)
# epoch12loss:67998653.6484375
# 0 0
# tf.Tensor(9273865.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1744558.4, shape=(), dtype=float32)
# tf.Tensor(1740634.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(365533.66, shape=(), dtype=float32)
# 2 0
# tf.Tensor(792027.8, shape=(), dtype=float32)
# tf.Tensor(792490.2, shape=(), dtype=float32)
# 2 1
# tf.Tensor(247036.45, shape=(), dtype=float32)
# tf.Tensor(197923.81, shape=(), dtype=float32)
# 2 2
# tf.Tensor(142690.97, shape=(), dtype=float32)
# 3 0
# tf.Tensor(601817.0, shape=(), dtype=float32)
# tf.Tensor(526572.9, shape=(), dtype=float32)
# 3 1
# tf.Tensor(191255.47, shape=(), dtype=float32)
# tf.Tensor(144710.06, shape=(), dtype=float32)
# 3 2
# tf.Tensor(123807.08, shape=(), dtype=float32)
# tf.Tensor(146297.6, shape=(), dtype=float32)
# 3 3
# tf.Tensor(117367.36, shape=(), dtype=float32)
# 4 0
# tf.Tensor(423057.34, shape=(), dtype=float32)
# tf.Tensor(366848.03, shape=(), dtype=float32)
# 4 1
# tf.Tensor(225123.86, shape=(), dtype=float32)
# tf.Tensor(105065.44, shape=(), dtype=float32)
# 4 2
# tf.Tensor(115488.94, shape=(), dtype=float32)
# tf.Tensor(80166.6, shape=(), dtype=float32)
# 4 3
# tf.Tensor(159657.73, shape=(), dtype=float32)
# tf.Tensor(104587.53, shape=(), dtype=float32)
# 4 4
# tf.Tensor(74538.89, shape=(), dtype=float32)
# 5 0
# tf.Tensor(402987.53, shape=(), dtype=float32)
# tf.Tensor(308884.2, shape=(), dtype=float32)
# 5 1
# tf.Tensor(178086.83, shape=(), dtype=float32)
# tf.Tensor(94298.805, shape=(), dtype=float32)
# 5 2
# tf.Tensor(116067.69, shape=(), dtype=float32)
# tf.Tensor(89639.37, shape=(), dtype=float32)
# 5 3
# tf.Tensor(170161.16, shape=(), dtype=float32)
# tf.Tensor(71431.086, shape=(), dtype=float32)
# 5 4
# tf.Tensor(95501.625, shape=(), dtype=float32)
# tf.Tensor(90166.1, shape=(), dtype=float32)
# 5 5
# tf.Tensor(74129.72, shape=(), dtype=float32)
# 6 0
# tf.Tensor(323712.44, shape=(), dtype=float32)
# tf.Tensor(240944.1, shape=(), dtype=float32)
# 6 1
# tf.Tensor(197913.7, shape=(), dtype=float32)
# tf.Tensor(69712.18, shape=(), dtype=float32)
# 6 2
# tf.Tensor(112039.11, shape=(), dtype=float32)
# tf.Tensor(58857.867, shape=(), dtype=float32)
# 6 3
# tf.Tensor(143563.39, shape=(), dtype=float32)
# tf.Tensor(69035.945, shape=(), dtype=float32)
# 6 4
# tf.Tensor(131669.8, shape=(), dtype=float32)
# tf.Tensor(101685.78, shape=(), dtype=float32)
# 6 5
# tf.Tensor(262254.06, shape=(), dtype=float32)
# tf.Tensor(81403.055, shape=(), dtype=float32)
# 6 6
# tf.Tensor(65004.51, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1557575.0, shape=(), dtype=float32)
# tf.Tensor(1409540.2, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2207044.2, shape=(), dtype=float32)
# tf.Tensor(2224251.8, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2833332.2, shape=(), dtype=float32)
# tf.Tensor(2908630.8, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2974030.8, shape=(), dtype=float32)
# tf.Tensor(2690272.0, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2909378.8, shape=(), dtype=float32)
# tf.Tensor(3139621.5, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3313018.5, shape=(), dtype=float32)
# tf.Tensor(3252716.2, shape=(), dtype=float32)
# 7 6
# tf.Tensor(3029501.2, shape=(), dtype=float32)
# tf.Tensor(3197652.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6535609.5, shape=(), dtype=float32)
# epoch13loss:66534447.59765625
# 0 0
# tf.Tensor(8935755.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1699995.5, shape=(), dtype=float32)
# tf.Tensor(1682016.6, shape=(), dtype=float32)
# 1 1
# tf.Tensor(361109.34, shape=(), dtype=float32)
# 2 0
# tf.Tensor(783190.06, shape=(), dtype=float32)
# tf.Tensor(778276.8, shape=(), dtype=float32)
# 2 1
# tf.Tensor(247079.5, shape=(), dtype=float32)
# tf.Tensor(171679.8, shape=(), dtype=float32)
# 2 2
# tf.Tensor(182888.22, shape=(), dtype=float32)
# 3 0
# tf.Tensor(605718.1, shape=(), dtype=float32)
# tf.Tensor(506024.78, shape=(), dtype=float32)
# 3 1
# tf.Tensor(208649.39, shape=(), dtype=float32)
# tf.Tensor(125572.7, shape=(), dtype=float32)
# 3 2
# tf.Tensor(107916.39, shape=(), dtype=float32)
# tf.Tensor(117804.32, shape=(), dtype=float32)
# 3 3
# tf.Tensor(128298.1, shape=(), dtype=float32)
# 4 0
# tf.Tensor(399796.22, shape=(), dtype=float32)
# tf.Tensor(365849.22, shape=(), dtype=float32)
# 4 1
# tf.Tensor(195291.45, shape=(), dtype=float32)
# tf.Tensor(109473.92, shape=(), dtype=float32)
# 4 2
# tf.Tensor(105005.76, shape=(), dtype=float32)
# tf.Tensor(87213.88, shape=(), dtype=float32)
# 4 3
# tf.Tensor(116067.6, shape=(), dtype=float32)
# tf.Tensor(66822.16, shape=(), dtype=float32)
# 4 4
# tf.Tensor(75080.445, shape=(), dtype=float32)
# 5 0
# tf.Tensor(374731.56, shape=(), dtype=float32)
# tf.Tensor(315904.16, shape=(), dtype=float32)
# 5 1
# tf.Tensor(201256.33, shape=(), dtype=float32)
# tf.Tensor(87603.4, shape=(), dtype=float32)
# 5 2
# tf.Tensor(87709.03, shape=(), dtype=float32)
# tf.Tensor(74235.37, shape=(), dtype=float32)
# 5 3
# tf.Tensor(124372.17, shape=(), dtype=float32)
# tf.Tensor(79231.586, shape=(), dtype=float32)
# 5 4
# tf.Tensor(63129.4, shape=(), dtype=float32)
# tf.Tensor(71134.53, shape=(), dtype=float32)
# 5 5
# tf.Tensor(89620.6, shape=(), dtype=float32)
# 6 0
# tf.Tensor(284027.78, shape=(), dtype=float32)
# tf.Tensor(234590.75, shape=(), dtype=float32)
# 6 1
# tf.Tensor(199984.44, shape=(), dtype=float32)
# tf.Tensor(68823.414, shape=(), dtype=float32)
# 6 2
# tf.Tensor(85927.59, shape=(), dtype=float32)
# tf.Tensor(55688.03, shape=(), dtype=float32)
# 6 3
# tf.Tensor(141596.69, shape=(), dtype=float32)
# tf.Tensor(47576.01, shape=(), dtype=float32)
# 6 4
# tf.Tensor(57046.484, shape=(), dtype=float32)
# tf.Tensor(47587.754, shape=(), dtype=float32)
# 6 5
# tf.Tensor(85781.54, shape=(), dtype=float32)
# tf.Tensor(47215.133, shape=(), dtype=float32)
# 6 6
# tf.Tensor(46805.64, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1480502.0, shape=(), dtype=float32)
# tf.Tensor(1370006.0, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2154046.5, shape=(), dtype=float32)
# tf.Tensor(2156867.0, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2807857.0, shape=(), dtype=float32)
# tf.Tensor(2865648.2, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2851996.0, shape=(), dtype=float32)
# tf.Tensor(2590672.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2865290.0, shape=(), dtype=float32)
# tf.Tensor(3042003.0, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3272404.0, shape=(), dtype=float32)
# tf.Tensor(3125455.2, shape=(), dtype=float32)
# 7 6
# tf.Tensor(2945152.8, shape=(), dtype=float32)
# tf.Tensor(3168350.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6500295.0, shape=(), dtype=float32)
# epoch14loss:64330699.96875
# 0 0
# tf.Tensor(8829604.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1687052.6, shape=(), dtype=float32)
# tf.Tensor(1635267.5, shape=(), dtype=float32)
# 1 1
# tf.Tensor(343056.97, shape=(), dtype=float32)
# 2 0
# tf.Tensor(790847.5, shape=(), dtype=float32)
# tf.Tensor(773703.56, shape=(), dtype=float32)
# 2 1
# tf.Tensor(225510.28, shape=(), dtype=float32)
# tf.Tensor(160998.31, shape=(), dtype=float32)
# 2 2
# tf.Tensor(127267.31, shape=(), dtype=float32)
# 3 0
# tf.Tensor(548062.8, shape=(), dtype=float32)
# tf.Tensor(498693.0, shape=(), dtype=float32)
# 3 1
# tf.Tensor(166016.55, shape=(), dtype=float32)
# tf.Tensor(150855.47, shape=(), dtype=float32)
# 3 2
# tf.Tensor(126610.29, shape=(), dtype=float32)
# tf.Tensor(93570.79, shape=(), dtype=float32)
# 3 3
# tf.Tensor(104437.375, shape=(), dtype=float32)
# 4 0
# tf.Tensor(416228.97, shape=(), dtype=float32)
# tf.Tensor(346028.44, shape=(), dtype=float32)
# 4 1
# tf.Tensor(175219.97, shape=(), dtype=float32)
# tf.Tensor(85750.37, shape=(), dtype=float32)
# 4 2
# tf.Tensor(126983.375, shape=(), dtype=float32)
# tf.Tensor(73485.24, shape=(), dtype=float32)
# 4 3
# tf.Tensor(279196.53, shape=(), dtype=float32)
# tf.Tensor(174063.11, shape=(), dtype=float32)
# 4 4
# tf.Tensor(68263.875, shape=(), dtype=float32)
# 5 0
# tf.Tensor(347328.6, shape=(), dtype=float32)
# tf.Tensor(294102.62, shape=(), dtype=float32)
# 5 1
# tf.Tensor(140379.75, shape=(), dtype=float32)
# tf.Tensor(85932.266, shape=(), dtype=float32)
# 5 2
# ...
# 6 2
# tf.Tensor(64055.777, shape=(), dtype=float32)
# tf.Tensor(43801.504, shape=(), dtype=float32)
# 6 3
# tf.Tensor(133517.66, shape=(), dtype=float32)
# tf.Tensor(67505.67, shape=(), dtype=float32)
# 6 4
# tf.Tensor(64644.676, shape=(), dtype=float32)
# tf.Tensor(51641.97, shape=(), dtype=float32)
# 6 5
# tf.Tensor(141010.81, shape=(), dtype=float32)
# tf.Tensor(80774.734, shape=(), dtype=float32)
# 6 6
# tf.Tensor(65343.883, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1427210.9, shape=(), dtype=float32)
# tf.Tensor(1267405.1, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2028300.8, shape=(), dtype=float32)
# tf.Tensor(2019904.0, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2635437.5, shape=(), dtype=float32)
# tf.Tensor(2680194.2, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2696938.2, shape=(), dtype=float32)
# tf.Tensor(2471626.0, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2703819.0, shape=(), dtype=float32)
# tf.Tensor(2861412.0, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3058354.0, shape=(), dtype=float32)
# tf.Tensor(3007629.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(2776498.0, shape=(), dtype=float32)
# tf.Tensor(2995611.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6362080.5, shape=(), dtype=float32)
# epoch17loss:61050501.51171875
# 0 0
# tf.Tensor(8135163.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1594789.9, shape=(), dtype=float32)
# tf.Tensor(1543440.0, shape=(), dtype=float32)
# 1 1
# tf.Tensor(357567.53, shape=(), dtype=float32)
# 2 0
# tf.Tensor(804062.0, shape=(), dtype=float32)
# tf.Tensor(736245.56, shape=(), dtype=float32)
# 2 1
# tf.Tensor(190680.12, shape=(), dtype=float32)
# tf.Tensor(158686.88, shape=(), dtype=float32)
# 2 2
# tf.Tensor(180699.53, shape=(), dtype=float32)
# 3 0
# tf.Tensor(511287.66, shape=(), dtype=float32)
# tf.Tensor(468740.1, shape=(), dtype=float32)
# 3 1
# tf.Tensor(164477.4, shape=(), dtype=float32)
# tf.Tensor(136146.14, shape=(), dtype=float32)
# 3 2
# tf.Tensor(76182.17, shape=(), dtype=float32)
# tf.Tensor(84147.45, shape=(), dtype=float32)
# 3 3
# tf.Tensor(122978.31, shape=(), dtype=float32)
# 4 0
# tf.Tensor(456863.38, shape=(), dtype=float32)
# tf.Tensor(339789.66, shape=(), dtype=float32)
# 4 1
# tf.Tensor(133628.19, shape=(), dtype=float32)
# tf.Tensor(75993.35, shape=(), dtype=float32)
# 4 2
# tf.Tensor(89892.05, shape=(), dtype=float32)
# tf.Tensor(124696.83, shape=(), dtype=float32)
# 4 3
# tf.Tensor(86024.17, shape=(), dtype=float32)
# tf.Tensor(56885.035, shape=(), dtype=float32)
# 4 4
# tf.Tensor(79525.53, shape=(), dtype=float32)
# 5 0
# tf.Tensor(328037.06, shape=(), dtype=float32)
# tf.Tensor(276980.34, shape=(), dtype=float32)
# 5 1
# tf.Tensor(186520.92, shape=(), dtype=float32)
# tf.Tensor(82399.57, shape=(), dtype=float32)
# 5 2
# tf.Tensor(70907.59, shape=(), dtype=float32)
# tf.Tensor(65480.33, shape=(), dtype=float32)
# 5 3
# tf.Tensor(101729.55, shape=(), dtype=float32)
# tf.Tensor(84279.17, shape=(), dtype=float32)
# 5 4
# tf.Tensor(56045.445, shape=(), dtype=float32)
# tf.Tensor(83824.24, shape=(), dtype=float32)
# 5 5
# tf.Tensor(83263.39, shape=(), dtype=float32)
# 6 0
# tf.Tensor(326436.44, shape=(), dtype=float32)
# tf.Tensor(215237.0, shape=(), dtype=float32)
# 6 1
# tf.Tensor(130645.766, shape=(), dtype=float32)
# tf.Tensor(50664.3, shape=(), dtype=float32)
# 6 2
# tf.Tensor(90238.04, shape=(), dtype=float32)
# tf.Tensor(93182.5, shape=(), dtype=float32)
# 6 3
# tf.Tensor(95783.164, shape=(), dtype=float32)
# tf.Tensor(46033.203, shape=(), dtype=float32)
# 6 4
# tf.Tensor(71834.05, shape=(), dtype=float32)
# tf.Tensor(55124.766, shape=(), dtype=float32)
# 6 5
# tf.Tensor(101143.664, shape=(), dtype=float32)
# tf.Tensor(48471.543, shape=(), dtype=float32)
# 6 6
# tf.Tensor(65262.9, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1340813.9, shape=(), dtype=float32)
# tf.Tensor(1247010.6, shape=(), dtype=float32)
# 7 1
# tf.Tensor(2008582.5, shape=(), dtype=float32)
# tf.Tensor(1981460.5, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2617267.0, shape=(), dtype=float32)
# tf.Tensor(2668254.2, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2662630.0, shape=(), dtype=float32)
# tf.Tensor(2380086.0, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2668035.2, shape=(), dtype=float32)
# tf.Tensor(2829890.2, shape=(), dtype=float32)
# 7 5
# tf.Tensor(3008292.8, shape=(), dtype=float32)
# tf.Tensor(2902779.5, shape=(), dtype=float32)
# 7 6
# tf.Tensor(2731339.5, shape=(), dtype=float32)
# tf.Tensor(2955013.5, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6291339.0, shape=(), dtype=float32)
# epoch18loss:59810911.36328125
# 0 0
# tf.Tensor(8014519.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1577688.0, shape=(), dtype=float32)
# tf.Tensor(1528765.5, shape=(), dtype=float32)
# 1 1
# tf.Tensor(333873.3, shape=(), dtype=float32)
# 2 0
# tf.Tensor(747581.3, shape=(), dtype=float32)
# tf.Tensor(714325.56, shape=(), dtype=float32)
# 2 1
# tf.Tensor(196997.53, shape=(), dtype=float32)
# tf.Tensor(163435.11, shape=(), dtype=float32)
# 2 2
# tf.Tensor(146707.1, shape=(), dtype=float32)
# 3 0
# tf.Tensor(529012.5, shape=(), dtype=float32)
# tf.Tensor(479892.2, shape=(), dtype=float32)
# 3 1
# tf.Tensor(128903.99, shape=(), dtype=float32)
# tf.Tensor(132675.97, shape=(), dtype=float32)
# 3 2
# tf.Tensor(105515.29, shape=(), dtype=float32)
# tf.Tensor(95454.66, shape=(), dtype=float32)
# 3 3
# tf.Tensor(97386.64, shape=(), dtype=float32)
# 4 0
# tf.Tensor(407618.2, shape=(), dtype=float32)
# tf.Tensor(319562.28, shape=(), dtype=float32)
# 4 1
# tf.Tensor(196530.94, shape=(), dtype=float32)
# tf.Tensor(79595.37, shape=(), dtype=float32)
# 4 2
# tf.Tensor(63353.133, shape=(), dtype=float32)
# tf.Tensor(84966.43, shape=(), dtype=float32)
# 4 3
# tf.Tensor(101723.68, shape=(), dtype=float32)
# tf.Tensor(66054.5, shape=(), dtype=float32)
# 4 4
# tf.Tensor(65383.074, shape=(), dtype=float32)
# 5 0
# tf.Tensor(328373.66, shape=(), dtype=float32)
# tf.Tensor(282142.97, shape=(), dtype=float32)
# 5 1
# tf.Tensor(110426.45, shape=(), dtype=float32)
# tf.Tensor(93714.05, shape=(), dtype=float32)
# 5 2
# tf.Tensor(81039.49, shape=(), dtype=float32)
# tf.Tensor(64238.96, shape=(), dtype=float32)
# 5 3
# tf.Tensor(81533.67, shape=(), dtype=float32)
# tf.Tensor(69619.73, shape=(), dtype=float32)
# 5 4
# tf.Tensor(61494.254, shape=(), dtype=float32)
# tf.Tensor(89687.79, shape=(), dtype=float32)
# 5 5
# tf.Tensor(81409.97, shape=(), dtype=float32)
# 6 0
# tf.Tensor(287760.5, shape=(), dtype=float32)
# tf.Tensor(203581.98, shape=(), dtype=float32)
# 6 1
# tf.Tensor(172585.6, shape=(), dtype=float32)
# tf.Tensor(66498.67, shape=(), dtype=float32)
# 6 2
# tf.Tensor(62925.5, shape=(), dtype=float32)
# tf.Tensor(65172.125, shape=(), dtype=float32)
# 6 3
# tf.Tensor(110933.61, shape=(), dtype=float32)
# tf.Tensor(54774.695, shape=(), dtype=float32)
# 6 4
# tf.Tensor(54899.594, shape=(), dtype=float32)
# tf.Tensor(51406.605, shape=(), dtype=float32)
# 6 5
# tf.Tensor(89376.37, shape=(), dtype=float32)
# tf.Tensor(57697.098, shape=(), dtype=float32)
# 6 6
# tf.Tensor(54612.492, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1311381.9, shape=(), dtype=float32)
# tf.Tensor(1205007.1, shape=(), dtype=float32)
# 7 1
# tf.Tensor(1938752.0, shape=(), dtype=float32)
# tf.Tensor(1943467.9, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2547716.2, shape=(), dtype=float32)
# tf.Tensor(2595655.8, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2637142.0, shape=(), dtype=float32)
# tf.Tensor(2378734.2, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2607653.5, shape=(), dtype=float32)
# tf.Tensor(2721410.2, shape=(), dtype=float32)
# 7 5
# tf.Tensor(2990407.5, shape=(), dtype=float32)
# tf.Tensor(2898744.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(2657237.0, shape=(), dtype=float32)
# tf.Tensor(2839841.8, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6263978.0, shape=(), dtype=float32)
# epoch19loss:58590556.9453125
# 0 0
# tf.Tensor(7870337.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1542932.2, shape=(), dtype=float32)
# tf.Tensor(1495458.4, shape=(), dtype=float32)
# 1 1
# tf.Tensor(334248.44, shape=(), dtype=float32)
# 2 0
# tf.Tensor(754246.06, shape=(), dtype=float32)
# tf.Tensor(715352.0, shape=(), dtype=float32)
# 2 1
# tf.Tensor(177677.67, shape=(), dtype=float32)
# tf.Tensor(148989.73, shape=(), dtype=float32)
# 2 2
# tf.Tensor(134138.64, shape=(), dtype=float32)
# 3 0
# tf.Tensor(492899.44, shape=(), dtype=float32)
# tf.Tensor(456114.97, shape=(), dtype=float32)
# 3 1
# tf.Tensor(142844.27, shape=(), dtype=float32)
# tf.Tensor(153983.28, shape=(), dtype=float32)
# 3 2
# tf.Tensor(80185.03, shape=(), dtype=float32)
# tf.Tensor(88949.875, shape=(), dtype=float32)
# 3 3
# tf.Tensor(108834.14, shape=(), dtype=float32)
# 4 0
# tf.Tensor(408083.4, shape=(), dtype=float32)
# tf.Tensor(332298.62, shape=(), dtype=float32)
# 4 1
# tf.Tensor(132177.7, shape=(), dtype=float32)
# tf.Tensor(78922.72, shape=(), dtype=float32)
# 4 2
# tf.Tensor(94567.69, shape=(), dtype=float32)
# tf.Tensor(69251.125, shape=(), dtype=float32)
# 4 3
# tf.Tensor(78834.64, shape=(), dtype=float32)
# tf.Tensor(61563.105, shape=(), dtype=float32)
# 4 4
# tf.Tensor(83421.445, shape=(), dtype=float32)
# 5 0
# tf.Tensor(314807.22, shape=(), dtype=float32)
# tf.Tensor(259610.97, shape=(), dtype=float32)
# 5 1
# tf.Tensor(165809.61, shape=(), dtype=float32)
# tf.Tensor(103723.08, shape=(), dtype=float32)
# 5 2
# tf.Tensor(55537.62, shape=(), dtype=float32)
# tf.Tensor(74913.1, shape=(), dtype=float32)
# 5 3
# tf.Tensor(111438.46, shape=(), dtype=float32)
# tf.Tensor(67375.47, shape=(), dtype=float32)
# 5 4
# tf.Tensor(52814.684, shape=(), dtype=float32)
# tf.Tensor(76667.11, shape=(), dtype=float32)
# 5 5
# tf.Tensor(102234.28, shape=(), dtype=float32)
# 6 0
# tf.Tensor(286012.66, shape=(), dtype=float32)
# tf.Tensor(207773.64, shape=(), dtype=float32)
# 6 1
# tf.Tensor(119845.625, shape=(), dtype=float32)
# tf.Tensor(56529.918, shape=(), dtype=float32)
# 6 2
# tf.Tensor(79134.67, shape=(), dtype=float32)
# tf.Tensor(51718.23, shape=(), dtype=float32)
# 6 3
# tf.Tensor(77184.914, shape=(), dtype=float32)
# tf.Tensor(50816.74, shape=(), dtype=float32)
# 6 4
# tf.Tensor(67198.11, shape=(), dtype=float32)
# tf.Tensor(66305.17, shape=(), dtype=float32)
# 6 5
# tf.Tensor(84472.766, shape=(), dtype=float32)
# tf.Tensor(52547.098, shape=(), dtype=float32)
# 6 6
# tf.Tensor(74030.14, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1278226.6, shape=(), dtype=float32)
# tf.Tensor(1168360.9, shape=(), dtype=float32)
# 7 1
# tf.Tensor(1921093.2, shape=(), dtype=float32)
# tf.Tensor(1866743.8, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2518888.5, shape=(), dtype=float32)
# tf.Tensor(2567626.5, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2564419.5, shape=(), dtype=float32)
# tf.Tensor(2302433.5, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2580174.5, shape=(), dtype=float32)
# tf.Tensor(2709037.8, shape=(), dtype=float32)
# 7 5
# tf.Tensor(2900166.2, shape=(), dtype=float32)
# tf.Tensor(2799307.5, shape=(), dtype=float32)
# 7 6
# tf.Tensor(2630054.5, shape=(), dtype=float32)
# tf.Tensor(2832025.0, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6181672.0, shape=(), dtype=float32)
# epoch20loss:57515042.91015625
# 0 0
# tf.Tensor(7720185.0, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1526671.2, shape=(), dtype=float32)
# tf.Tensor(1487701.1, shape=(), dtype=float32)
# 1 1
# tf.Tensor(313193.06, shape=(), dtype=float32)
# 2 0
# tf.Tensor(719949.3, shape=(), dtype=float32)
# tf.Tensor(696044.3, shape=(), dtype=float32)
# 2 1
# tf.Tensor(203976.03, shape=(), dtype=float32)
# tf.Tensor(163606.38, shape=(), dtype=float32)
# 2 2
# tf.Tensor(113466.85, shape=(), dtype=float32)
# 3 0
# tf.Tensor(505833.62, shape=(), dtype=float32)
# tf.Tensor(477822.5, shape=(), dtype=float32)
# 3 1
# tf.Tensor(129617.375, shape=(), dtype=float32)
# tf.Tensor(113421.18, shape=(), dtype=float32)
# 3 2
# tf.Tensor(82726.6, shape=(), dtype=float32)
# tf.Tensor(100100.39, shape=(), dtype=float32)
# 3 3
# tf.Tensor(90056.92, shape=(), dtype=float32)
# 4 0
# tf.Tensor(366781.12, shape=(), dtype=float32)
# tf.Tensor(311493.03, shape=(), dtype=float32)
# 4 1
# tf.Tensor(174800.97, shape=(), dtype=float32)
# tf.Tensor(97041.78, shape=(), dtype=float32)
# 4 2
# tf.Tensor(63789.74, shape=(), dtype=float32)
# tf.Tensor(59838.457, shape=(), dtype=float32)
# 4 3
# tf.Tensor(100050.44, shape=(), dtype=float32)
# tf.Tensor(58239.383, shape=(), dtype=float32)
# 4 4
# tf.Tensor(61064.84, shape=(), dtype=float32)
# 5 0
# tf.Tensor(350778.8, shape=(), dtype=float32)
# tf.Tensor(273340.22, shape=(), dtype=float32)
# 5 1
# tf.Tensor(107923.88, shape=(), dtype=float32)
# tf.Tensor(84765.92, shape=(), dtype=float32)
# 5 2
# tf.Tensor(91340.15, shape=(), dtype=float32)
# tf.Tensor(78203.91, shape=(), dtype=float32)
# 5 3
# tf.Tensor(76641.76, shape=(), dtype=float32)
# tf.Tensor(68457.4, shape=(), dtype=float32)
# 5 4
# tf.Tensor(70590.35, shape=(), dtype=float32)
# tf.Tensor(88683.3, shape=(), dtype=float32)
# 5 5
# tf.Tensor(79051.06, shape=(), dtype=float32)
# 6 0
# tf.Tensor(274079.7, shape=(), dtype=float32)
# tf.Tensor(199034.44, shape=(), dtype=float32)
# 6 1
# tf.Tensor(175579.2, shape=(), dtype=float32)
# tf.Tensor(78729.38, shape=(), dtype=float32)
# 6 2
# tf.Tensor(59461.81, shape=(), dtype=float32)
# tf.Tensor(51875.11, shape=(), dtype=float32)
# 6 3
# tf.Tensor(115317.79, shape=(), dtype=float32)
# tf.Tensor(52070.973, shape=(), dtype=float32)
# 6 4
# tf.Tensor(53809.133, shape=(), dtype=float32)
# tf.Tensor(49508.406, shape=(), dtype=float32)
# 6 5
# tf.Tensor(101871.08, shape=(), dtype=float32)
# tf.Tensor(60546.06, shape=(), dtype=float32)
# 6 6
# tf.Tensor(54812.555, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1264288.0, shape=(), dtype=float32)
# tf.Tensor(1147717.9, shape=(), dtype=float32)
# 7 1
# tf.Tensor(1873935.9, shape=(), dtype=float32)
# tf.Tensor(1857110.8, shape=(), dtype=float32)
# 7 2
# tf.Tensor(2453673.0, shape=(), dtype=float32)
# tf.Tensor(2487250.0, shape=(), dtype=float32)
# 7 3
# tf.Tensor(2535079.0, shape=(), dtype=float32)
# tf.Tensor(2296021.2, shape=(), dtype=float32)
# 7 4
# tf.Tensor(2514483.2, shape=(), dtype=float32)
# tf.Tensor(2615038.8, shape=(), dtype=float32)
# 7 5
# tf.Tensor(2867799.5, shape=(), dtype=float32)
# tf.Tensor(2785990.8, shape=(), dtype=float32)
# 7 6
# tf.Tensor(2552704.0, shape=(), dtype=float32)
# tf.Tensor(2731800.2, shape=(), dtype=float32)
# 7 7
# tf.Tensor(6156512.0, shape=(), dtype=float32)
# epoch21loss:56573348.3046875
# 0 0
# tf.Tensor(7572150.5, shape=(), dtype=float32)
# 1 0
# tf.Tensor(1499685.9, shape=(), dtype=float32)
# tf.Tensor(1454920.6, shape=(), dtype=float32)
# 1 1
# tf.Tensor(340890.72, shape=(), dtype=float32)
# 2 0
# tf.Tensor(763805.9, shape=(), dtype=float32)
# tf.Tensor(703846.56, shape=(), dtype=float32)
# 2 1
# tf.Tensor(173750.81, shape=(), dtype=float32)
# tf.Tensor(143068.86, shape=(), dtype=float32)
# 2 2
# tf.Tensor(133153.92, shape=(), dtype=float32)
# 3 0
# tf.Tensor(484497.6, shape=(), dtype=float32)
# tf.Tensor(446715.88, shape=(), dtype=float32)
# 3 1
# tf.Tensor(159194.86, shape=(), dtype=float32)
# tf.Tensor(154830.92, shape=(), dtype=float32)
# 3 2
# tf.Tensor(68782.78, shape=(), dtype=float32)
# tf.Tensor(83922.32, shape=(), dtype=float32)
# 3 3
# tf.Tensor(120693.25, shape=(), dtype=float32)
# 4 0
# tf.Tensor(413295.66, shape=(), dtype=float32)
# tf.Tensor(318024.28, shape=(), dtype=float32)
# 4 1
# tf.Tensor(123049.26, shape=(), dtype=float32)
# tf.Tensor(78608.984, shape=(), dtype=float32)
# 4 2
# tf.Tensor(83098.47, shape=(), dtype=float32)
# tf.Tensor(69099.4, shape=(), dtype=float32)
# 4 3
# tf.Tensor(74579.414, shape=(), dtype=float32)
# tf.Tensor(53477.316, shape=(), dtype=float32)
# 4 4
# tf.Tensor(67336.33, shape=(), dtype=float32)
# 5 0
# tf.Tensor(298922.47, shape=(), dtype=float32)
# tf.Tensor(250194.19, shape=(), dtype=float32)
# 5 1
# tf.Tensor(146814.56, shape=(), dtype=float32)
# tf.Tensor(98781.19, shape=(), dtype=float32)
# 5 2
# tf.Tensor(53596.645, shape=(), dtype=float32)
# tf.Tensor(76650.42, shape=(), dtype=float32)
# 5 3
# tf.Tensor(106484.55, shape=(), dtype=float32)
# tf.Tensor(76302.51, shape=(), dtype=float32)
# 5 4
# tf.Tensor(45595.797, shape=(), dtype=float32)
# tf.Tensor(74208.6, shape=(), dtype=float32)
# 5 5
# tf.Tensor(84338.26, shape=(), dtype=float32)
# 6 0
# tf.Tensor(315985.38, shape=(), dtype=float32)
# tf.Tensor(201658.94, shape=(), dtype=float32)
# 6 1
# tf.Tensor(102876.67, shape=(), dtype=float32)
# tf.Tensor(58070.973, shape=(), dtype=float32)
# 6 2
# tf.Tensor(79246.695, shape=(), dtype=float32)
# tf.Tensor(49568.645, shape=(), dtype=float32)
# 6 3
# tf.Tensor(66455.28, shape=(), dtype=float32)
# tf.Tensor(46140.156, shape=(), dtype=float32)
# 6 4
# tf.Tensor(54977.684, shape=(), dtype=float32)
# tf.Tensor(47725.527, shape=(), dtype=float32)
# 6 5
# tf.Tensor(67745.95, shape=(), dtype=float32)
# tf.Tensor(42696.477, shape=(), dtype=float32)
# 6 6
# tf.Tensor(52928.75, shape=(), dtype=float32)
# 7 0
# tf.Tensor(1225900.8, shape=(), dtype=float32)
